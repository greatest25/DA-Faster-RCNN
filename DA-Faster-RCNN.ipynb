# %% [markdown]
# # 环境设置

# %%
import sys
import os
import numpy as np
import torch

# 将 detectron2 的源码路径添加到 Python 的搜索路径中
# 这是我们从源码编译 detectron2 的文件夹
d2_path = '/mnt/lyh/DA-FasterCNN/detectron2-main'
if d2_path not in sys.path:
    sys.path.insert(0, d2_path)

# 验证路径是否已添加
print("sys.path has been updated:")
print(sys.path)
# Out:
# sys.path has been updated:
# ['/mnt/lyh/DA-FasterCNN/detectron2-main', '/home/refrain/anaconda3/envs/lyh_env/lib/python310.zip', '/home/refrain/anaconda3/envs/lyh_env/lib/python3.10', '/home/refrain/anaconda3/envs/lyh_env/lib/python3.10/lib-dynload', '', '/home/refrain/anaconda3/envs/lyh_env/lib/python3.10/site-packages']

# %% [markdown]
# # Check the installation
# The right output running the following cell should be:<br><br>
# nvcc: NVIDIA (R) Cuda compiler driver<br>
# Copyright (c) 2005-2020 NVIDIA Corporation<br>
# Built on Wed_Sep_21_10:33:58_PDT_2022<br>
# Cuda compilation tools, release 11.8, V11.8.89<br>
# Build cuda_11.8.r11.8/compiler.31833905_0<br>
# torch:  2.0 ; cuda:  cu118<br>
# detectron2: 0.6<br>

# %%
import torch, detectron2
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# torch:  2.0 ; cuda:  cu118
# detectron2: 0.6
# torch:  2.0 ; cuda:  cu118
# detectron2: 0.6

# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()
import numpy as np
import cv2
import random
from detectron2 import model_zoo
from detectron2.config import get_cfg
import logging
import os
from collections import OrderedDict
from torch.nn.parallel import DistributedDataParallel
import detectron2.utils.comm as comm
from detectron2.checkpoint import DetectionCheckpointer, PeriodicCheckpointer
from detectron2.data import MetadataCatalog, build_detection_test_loader, build_detection_train_loader
from detectron2.modeling import build_model
from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.utils.events import EventStorage
from detectron2.engine import default_argument_parser, default_setup, default_writers, launch
import torch, torchvision
from detectron2.data.datasets import register_coco_instances, load_coco_json, register_pascal_voc
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# /mnt/lyh/DA-FasterCNN/detectron2-main/detectron2/model_zoo/model_zoo.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# # 数据准备与注册

# %%
# 数据准备 (Cityscapes -> PASCAL VOC 格式)
# !!! 注意：此单元格仅在需要从原始数据生成VOC格式时运行一次。
# 如果 "/mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007" 目录中已有数据，请跳过此单元格。

import os, json, glob, shutil, pprint
import cv2
import xml.etree.ElementTree as ET

# --- 配置路径 ---
CITY_ROOT = "/mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscapes_raw"
OUT_BASE = "/mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007"
CLASSES = ['car','person','rider','truck','bus','train','motorcycle','bicycle']

# --- 确保输出目录存在 ---
os.makedirs(os.path.join(OUT_BASE, "JPEGImages"), exist_ok=True)
os.makedirs(os.path.join(OUT_BASE, "Annotations"), exist_ok=True)
os.makedirs(os.path.join(OUT_BASE, "ImageSets", "Main"), exist_ok=True)
print(f"输出目录 {OUT_BASE} 已准备好。")

# --- 辅助函数 ---
def write_voc_xml(img_id, fname, w, h, objs, out_path):
    # ... (此函数内容保持不变) ...
    ann = ET.Element("annotation")
    ET.SubElement(ann, "folder").text = "VOC2007"
    ET.SubElement(ann, "filename").text = fname
    size = ET.SubElement(ann, "size")
    ET.SubElement(size, "width").text = str(w)
    ET.SubElement(size, "height").text = str(h)
    ET.SubElement(size, "depth").text = "3"
    ET.SubElement(ann, "segmented").text = "0"
    for cls, (x1, y1, x2, y2) in objs:
        obj = ET.SubElement(ann, "object")
        ET.SubElement(obj, "name").text = cls
        ET.SubElement(obj, "pose").text = "Unspecified"
        ET.SubElement(obj, "truncated").text = "0"
        ET.SubElement(obj, "difficult").text = "0"
        bb = ET.SubElement(obj, "bndbox")
        ET.SubElement(bb, "xmin").text = str(max(1, int(x1)))
        ET.SubElement(bb, "ymin").text = str(max(1, int(y1)))
        ET.SubElement(bb, "xmax").text = str(int(x2))
        ET.SubElement(bb, "ymax").text = str(int(y2))
    ET.ElementTree(ann).write(out_path, encoding="utf-8", xml_declaration=True)

def polygon_to_bbox(poly):
    xs = [p[0] for p in poly]
    ys = [p[1] for p in poly]
    return min(xs), min(ys), max(xs), max(ys)

def collect_ids(img_root, suffix='_leftImg8bit.png'):
    # ... (此函数内容可简化以提高鲁棒性) ...
    ids = {}
    for f in glob.glob(os.path.join(img_root, "**", f"*{suffix}"), recursive=True):
         bn = os.path.basename(f)
         img_id = bn.split("_leftImg8bit")[0]
         ids[img_id] = f
    return ids

# --- 1. 收集所有图像ID和路径 ---
clear_train_ids = collect_ids(os.path.join(CITY_ROOT, "leftImg8bit", "train"))
clear_val_ids   = collect_ids(os.path.join(CITY_ROOT, "leftImg8bit", "val"))

# 查找并收集 foggy 图像
foggy_root_path = os.path.join(CITY_ROOT, "leftImg8bit_foggyDBF")
foggy_train_ids = collect_ids(foggy_root_path, suffix='_leftImg8bit_foggy_beta_0.02.png')

all_image_paths = {**clear_train_ids, **clear_val_ids, **foggy_train_ids}
print(f"总共找到 {len(all_image_paths)} 个唯一的图像ID。")

# --- 2. 收集所有标注文件 ---
gt_files = glob.glob(os.path.join(CITY_ROOT, "gtFine", "**", "*_gtFine_polygons.json"), recursive=True)
gt_index = {os.path.basename(p).replace("_gtFine_polygons.json", ""): p for p in gt_files}
print(f"找到 {len(gt_index)} 个标注文件。")

# --- 3. 转换图像和标注 ---
for img_id, img_src in all_image_paths.items():
    img = cv2.imread(img_src)
    if img is None: continue
    h, w = img.shape[:2]
    
    # 保存为jpg
    out_jpg = os.path.join(OUT_BASE, "JPEGImages", f"{img_id}.jpg")
    cv2.imwrite(out_jpg, img)

    # 转换标注
    objs = []
    if img_id in gt_index:
        with open(gt_index[img_id], "r") as f:
            data = json.load(f)
        for s in data.get("objects", []):
            if s.get("label") in CLASSES:
                objs.append((s["label"], polygon_to_bbox(s["polygon"])))
    
    xml_out = os.path.join(OUT_BASE, "Annotations", f"{img_id}.xml")
    write_voc_xml(img_id, f"{img_id}.jpg", w, h, objs, xml_out)

print("图像和标注转换完成。")

# --- 4. 生成 ImageSets 列表 ---
def dump_list(fn, ids):
    path = os.path.join(OUT_BASE, "ImageSets", "Main", fn + ".txt")
    with open(path, "w") as f:
        f.write("\n".join(sorted(ids)))
    print(f"已写入 {len(ids)} 个ID到 {path}")

dump_list("train_s", clear_train_ids.keys())
dump_list("train_t", foggy_train_ids.keys())
dump_list("test_t",  clear_val_ids.keys())

print("\n数据准备完成！VOC数据集位于:", OUT_BASE)
# Out:
# 输出目录 /mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007 已准备好。
# 总共找到 3475 个唯一的图像ID。
# 找到 5000 个标注文件。
# 图像和标注转换完成。
# 已写入 2975 个ID到 /mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007/ImageSets/Main/train_s.txt
# 已写入 3475 个ID到 /mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007/ImageSets/Main/train_t.txt
# 已写入 500 个ID到 /mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007/ImageSets/Main/test_t.txt
#
# 数据准备完成！VOC数据集位于: /mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007
# 图像和标注转换完成。
# 已写入 2975 个ID到 /mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007/ImageSets/Main/train_s.txt
# 已写入 3475 个ID到 /mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007/ImageSets/Main/train_t.txt
# 已写入 500 个ID到 /mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007/ImageSets/Main/test_t.txt
#
# 数据准备完成！VOC数据集位于: /mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007

# %%
# 注册数据集
# 运行此单元格来清理并重新注册所有需要的数据集。
# 每次启动 notebook/kernel 进行训练或评估前，都需要运行一次。

from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.data.datasets import register_pascal_voc
from pprint import pprint

def register_datasets(voc_root):
    """
    安全地注销并重新注册所有 Cityscapes VOC 数据集。
    """
    classes = ['car','person','rider','truck','bus','train','motorcycle','bicycle']
    
    # 定义需要注册的数据集和对应的txt文件名
    split_map = {
        "city_trainS": "train_s", # 源域训练集
        "city_trainT": "train_t", # 目标域训练集
        "city_testT": "test_t",   # 目标域测试集
    }

    # 1. 安全地注销已存在的数据集，避免重注册错误
    for name in split_map.keys():
        if name in DatasetCatalog.list():
            DatasetCatalog.remove(name)
        if name in MetadataCatalog.list():
            MetadataCatalog.remove(name)
    
    print(f"已清理旧的注册: {list(split_map.keys())}")

    # 2. 重新注册所有数据集
    for name, split_file in split_map.items():
        register_pascal_voc(name, voc_root, split_file, 2007, classes)
    
    print("\n已重新注册数据集:")
    
    # 3. 打印统计信息以供验证
    for name in split_map.keys():
        try:
            num_samples = len(DatasetCatalog.get(name))
            print(f"- {name}: {num_samples} 个样本")
        except Exception as e:
            print(f"- {name}: 注册失败! {e}")

# --- 执行注册 ---
VOC_ROOT_PATH = "/mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007/"
register_datasets(VOC_ROOT_PATH)

# 可选：预览一条数据记录来检查格式是否正确
print("\n预览 'city_trainS' 的第一条记录:")
pprint(DatasetCatalog.get("city_trainS")[0])
# Out:
# 已清理旧的注册: ['city_trainS', 'city_trainT', 'city_testT']
#
# 已重新注册数据集:
# - city_trainS: 2975 个样本
# - city_trainS: 2975 个样本
# - city_trainT: 3475 个样本
# - city_testT: 500 个样本
#
# 预览 'city_trainS' 的第一条记录:
# - city_trainT: 3475 个样本
# - city_testT: 500 个样本
#
# 预览 'city_trainS' 的第一条记录:
# {'annotations': [{'bbox': [608.0, 419.0, 807.0, 532.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [144.0, 428.0, 304.0, 502.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [144.0, 428.0, 304.0, 502.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1961.0, 487.0, 2047.0, 526.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1511.0, 445.0, 1660.0, 499.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1478.0, 455.0, 1634.0, 514.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1861.0, 480.0, 1937.0, 500.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1871.0, 485.0, 1956.0, 513.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1720.0, 449.0, 1864.0, 509.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [144.0, 428.0, 304.0, 502.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [786.0, 445.0, 828.0, 490.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 7},
#                  {'bbox': [886.0, 445.0, 913.0, 498.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 1},
#                  {'bbox': [900.0, 443.0, 934.0, 498.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 1},
#                  {'bbox': [608.0, 419.0, 807.0, 532.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1830.0, 435.0, 1887.0, 548.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 2},
#                  {'bbox': [1838.0, 467.0, 1877.0, 547.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 7}],
#  'file_name': '/mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007/JPEGImages/aachen_000000_000019.jpg',
#  'height': 1024,
#  'image_id': 'aachen_000000_000019',
#  'width': 2048}
# {'annotations': [{'bbox': [608.0, 419.0, 807.0, 532.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [144.0, 428.0, 304.0, 502.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [144.0, 428.0, 304.0, 502.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1961.0, 487.0, 2047.0, 526.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1511.0, 445.0, 1660.0, 499.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1478.0, 455.0, 1634.0, 514.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1861.0, 480.0, 1937.0, 500.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1871.0, 485.0, 1956.0, 513.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1720.0, 449.0, 1864.0, 509.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [144.0, 428.0, 304.0, 502.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [786.0, 445.0, 828.0, 490.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 7},
#                  {'bbox': [886.0, 445.0, 913.0, 498.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 1},
#                  {'bbox': [900.0, 443.0, 934.0, 498.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 1},
#                  {'bbox': [608.0, 419.0, 807.0, 532.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 0},
#                  {'bbox': [1830.0, 435.0, 1887.0, 548.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 2},
#                  {'bbox': [1838.0, 467.0, 1877.0, 547.0],
#                   'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#                   'category_id': 7}],
#  'file_name': '/mnt/lyh/DA-FasterCNN/DA-Faster-RCNN/datasets/cityscape/VOC2007/JPEGImages/aachen_000000_000019.jpg',
#  'height': 1024,
#  'image_id': 'aachen_000000_000019',
#  'width': 2048}

# %% [markdown]
# #Training Loop Definition
# Run the following block

# %%
logger = logging.getLogger("detectron2")

def do_train(cfg_source, cfg_target, model, resume = False):

    model.train()
    optimizer = build_optimizer(cfg_source, model)
    scheduler = build_lr_scheduler(cfg_source, optimizer)
    checkpointer = DetectionCheckpointer(model, cfg_source.OUTPUT_DIR, optimizer=optimizer, scheduler=scheduler)

    start_iter = (checkpointer.resume_or_load(cfg_source.MODEL.WEIGHTS, resume=resume).get("iteration", -1) + 1)
    max_iter = cfg_source.SOLVER.MAX_ITER

    periodic_checkpointer = PeriodicCheckpointer(checkpointer, cfg_source.SOLVER.CHECKPOINT_PERIOD, max_iter=max_iter)
    writers = default_writers(cfg_source.OUTPUT_DIR, max_iter) if comm.is_main_process() else []

    data_loader_source = build_detection_train_loader(cfg_source)
    data_loader_target = build_detection_train_loader(cfg_target)
    logger.info("Starting training from iteration {}".format(start_iter))

    lambda_hyper = 0.1

    with EventStorage(start_iter) as storage:
        for data_source, data_target, iteration in zip(data_loader_source, data_loader_target, range(start_iter, max_iter)):
            storage.iter = iteration

            loss_dict = model(data_source, False, 1)
            loss_dict_target = model(data_target, True, 1)
            
            loss_dict["loss_image_d"] += loss_dict_target["loss_image_d"]
            loss_dict["loss_instance_d"] += loss_dict_target["loss_instance_d"]
            loss_dict["loss_consistency_d"] += loss_dict_target["loss_consistency_d"]

            loss_dict["loss_image_d"] *= ( 0.5 * lambda_hyper)
            loss_dict["loss_instance_d"] *= ( 0.5 * lambda_hyper)
            loss_dict["loss_consistency_d"] *= ( 0.5 * lambda_hyper)

            losses = sum(loss_dict.values())
            assert torch.isfinite(losses).all(), loss_dict

            loss_dict_reduced = {k: v.item() for k, v in comm.reduce_dict(loss_dict).items()}
            losses_reduced = sum(loss for loss in loss_dict_reduced.values())
            if comm.is_main_process():
                storage.put_scalars(total_loss=losses_reduced, **loss_dict_reduced)

            optimizer.zero_grad()
            losses.backward()
            optimizer.step()
            storage.put_scalar("lr", optimizer.param_groups[0]["lr"], smoothing_hint=False)
            scheduler.step()

            if iteration - start_iter > 5 and ((iteration + 1) % 50 == 0 or iteration == max_iter - 1):
                for writer in writers:
                    writer.write()
            periodic_checkpointer.step(iteration)

# %% [markdown]
# #Configuration Definition
# Define the configuration for the source (cfg_source) and target dataset (cfg_target). The cfg_source contains also the parameters which will be used by the network such us:<br>
# learning rate, number of training iterations, weight decay, number of classes etc...
#
# ## Backbone for Faster RCNN
# this implementations works with three kind of backbone:<br> FPN: "COCO-Detection/faster_rcnn_R_50_FPN_1x.yaml"<br>
# DC5: "COCO-Detection/faster_rcnn_R_50_DC5_1x.yaml"<br>
# C4: "COCO-Detection/faster_rcnn_R_50_C4_1x.yaml"<br>
#
# You can also use their variants such us faster_rcnn_R_101_C4_3x, faster_rcnn_R_50_DC5_3x, faster_rcnn_R_101_DC5_3x, etc...

# %%
cfg_source = get_cfg()
cfg_source.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_1x.yaml"))
cfg_source.DATASETS.TRAIN = ("city_trainS",)
cfg_source.DATALOADER.NUM_WORKERS = 2
cfg_source.MODEL.WEIGHTS = "/mnt/lyh/DA-FasterCNN/weights/COCO-Detection/faster_rcnn_R_50_FPN_1x/model_final_b275ba.pkl"
#cfg_source.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_1x.yaml")
cfg_source.SOLVER.IMS_PER_BATCH = 4
cfg_source.SOLVER.BASE_LR = 0.0005
cfg_source.SOLVER.WARMUP_FACTOR = 1.0 / 100
cfg_source.SOLVER.WARMUP_ITERS = 1000
cfg_source.SOLVER.MAX_ITER = 5000
cfg_source.INPUT.MIN_SIZE_TRAIN = (600,)
cfg_source.INPUT.MIN_SIZE_TEST = 0
os.makedirs(cfg_source.OUTPUT_DIR, exist_ok=True)
cfg_source.MODEL.ROI_HEADS.NUM_CLASSES = 8
model = build_model(cfg_source)

cfg_target = get_cfg()
cfg_target.DATALOADER.FILTER_EMPTY_ANNOTATIONS = False
cfg_target.DATASETS.TRAIN = ("city_trainT",)
cfg_target.INPUT.MIN_SIZE_TRAIN = (600,)
cfg_target.DATALOADER.NUM_WORKERS = 0
cfg_target.SOLVER.IMS_PER_BATCH = 4
# Out:
# build_resnet_fpn_backbone

# %%
do_train(cfg_source,cfg_target,model)
# Out:
# WARNING [10/21 08:50:35 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [10/21 08:50:35 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /mnt/lyh/DA-FasterCNN/weights/COCO-Detection/faster_rcnn_R_50_FPN_1x/model_final_b275ba.pkl ...
# [10/21 08:50:35 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /mnt/lyh/DA-FasterCNN/weights/COCO-Detection/faster_rcnn_R_50_FPN_1x/model_final_b275ba.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (9, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (9,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (32, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (32,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# discriminator.net.0.weight
# discriminator.net.2.weight
# discriminator.net.4.weight
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.discriminatorProposal.net.weight
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (9,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (32, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (32,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# discriminator.net.0.weight
# discriminator.net.2.weight
# discriminator.net.4.weight
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.discriminatorProposal.net.weight
# [10/21 08:50:35 d2.data.build]: Removed 10 images with no usable annotations. 2965 images left.
# [10/21 08:50:35 d2.data.build]: Distribution of instances among all 8 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |    car     | 27155        |   person   | 17994        |   rider    | 1807         |
# |   truck    | 489          |    bus     | 385          |   train    | 171          |
# | motorcycle | 739          |  bicycle   | 3729         |            |              |
# |   total    | 52469        |            |              |            |              |
# [10/21 08:50:35 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(600,), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/21 08:50:35 d2.data.build]: Using training sampler TrainingSampler
# [10/21 08:50:35 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/21 08:50:35 d2.data.build]: Distribution of instances among all 8 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |    car     | 27155        |   person   | 17994        |   rider    | 1807         |
# |   truck    | 489          |    bus     | 385          |   train    | 171          |
# | motorcycle | 739          |  bicycle   | 3729         |            |              |
# |   total    | 52469        |            |              |            |              |
# [10/21 08:50:35 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(600,), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/21 08:50:35 d2.data.build]: Using training sampler TrainingSampler
# [10/21 08:50:35 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/21 08:50:35 d2.data.common]: Serializing 2965 elements to byte tensors and concatenating them all ...
# [10/21 08:50:35 d2.data.common]: Serialized dataset takes 3.93 MiB
# [10/21 08:50:35 d2.data.common]: Serializing 2965 elements to byte tensors and concatenating them all ...
# [10/21 08:50:35 d2.data.common]: Serialized dataset takes 3.93 MiB
# [10/21 08:50:35 d2.data.build]: Making batched data loader with batch_size=4
# [10/21 08:50:35 d2.data.build]: Making batched data loader with batch_size=4
# [10/21 08:50:35 d2.data.build]: Distribution of instances among all 8 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |    car     | 31822        |   person   | 21413        |   rider    | 2363         |
# |   truck    | 582          |    bus     | 483          |   train    | 194          |
# | motorcycle | 888          |  bicycle   | 4904         |            |              |
# |   total    | 62649        |            |              |            |              |
# [10/21 08:50:35 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(600,), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/21 08:50:35 d2.data.build]: Using training sampler TrainingSampler
# [10/21 08:50:35 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/21 08:50:35 d2.data.common]: Serializing 3475 elements to byte tensors and concatenating them all ...
# [10/21 08:50:35 d2.data.build]: Distribution of instances among all 8 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |    car     | 31822        |   person   | 21413        |   rider    | 2363         |
# |   truck    | 582          |    bus     | 483          |   train    | 194          |
# | motorcycle | 888          |  bicycle   | 4904         |            |              |
# |   total    | 62649        |            |              |            |              |
# [10/21 08:50:35 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(600,), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/21 08:50:35 d2.data.build]: Using training sampler TrainingSampler
# [10/21 08:50:35 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/21 08:50:35 d2.data.common]: Serializing 3475 elements to byte tensors and concatenating them all ...
# [10/21 08:50:35 d2.data.common]: Serialized dataset takes 4.66 MiB
# [10/21 08:50:35 d2.data.build]: Making batched data loader with batch_size=4
# [10/21 08:50:35 detectron2]: Starting training from iteration 0
# [10/21 08:50:35 d2.data.common]: Serialized dataset takes 4.66 MiB
# [10/21 08:50:35 d2.data.build]: Making batched data loader with batch_size=4
# [10/21 08:50:35 detectron2]: Starting training from iteration 0
# /home/refrain/anaconda3/envs/lyh_env/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [10/21 08:50:54 d2.utils.events]:  iter: 49  total_loss: 3.013  loss_cls: 1.699  loss_box_reg: 0.687  loss_rpn_cls: 0.1223  loss_rpn_loc: 0.2381  loss_image_d: 0.06936  loss_instance_d: 0.06531  loss_consistency_d: 0.0005173     lr: 2.9255e-05  max_mem: 4885M
# [10/21 08:51:12 d2.utils.events]:  eta: 0:29:47  iter: 99  total_loss: 1.995  loss_cls: 0.7895  loss_box_reg: 0.6646  loss_rpn_cls: 0.09943  loss_rpn_loc: 0.3001  loss_image_d: 0.06927  loss_instance_d: 0.06101  loss_consistency_d: 0.0008913     lr: 5.4005e-05  max_mem: 4885M
# [10/21 08:51:12 d2.utils.events]:  eta: 0:29:47  iter: 99  total_loss: 1.995  loss_cls: 0.7895  loss_box_reg: 0.6646  loss_rpn_cls: 0.09943  loss_rpn_loc: 0.3001  loss_image_d: 0.06927  loss_instance_d: 0.06101  loss_consistency_d: 0.0008913     lr: 5.4005e-05  max_mem: 4885M
# [10/21 08:51:31 d2.utils.events]:  eta: 0:29:28  iter: 149  total_loss: 1.646  loss_cls: 0.5828  loss_box_reg: 0.6551  loss_rpn_cls: 0.08639  loss_rpn_loc: 0.2415  loss_image_d: 0.06937  loss_instance_d: 0.05263  loss_consistency_d: 0.001269     lr: 7.8755e-05  max_mem: 4885M
# [10/21 08:51:31 d2.utils.events]:  eta: 0:29:28  iter: 149  total_loss: 1.646  loss_cls: 0.5828  loss_box_reg: 0.6551  loss_rpn_cls: 0.08639  loss_rpn_loc: 0.2415  loss_image_d: 0.06937  loss_instance_d: 0.05263  loss_consistency_d: 0.001269     lr: 7.8755e-05  max_mem: 4885M
# [10/21 08:51:49 d2.utils.events]:  eta: 0:29:04  iter: 199  total_loss: 1.738  loss_cls: 0.5567  loss_box_reg: 0.6558  loss_rpn_cls: 0.08792  loss_rpn_loc: 0.2675  loss_image_d: 0.06938  loss_instance_d: 0.04151  loss_consistency_d: 0.003192     lr: 0.00010351  max_mem: 4886M
# [10/21 08:51:49 d2.utils.events]:  eta: 0:29:04  iter: 199  total_loss: 1.738  loss_cls: 0.5567  loss_box_reg: 0.6558  loss_rpn_cls: 0.08792  loss_rpn_loc: 0.2675  loss_image_d: 0.06938  loss_instance_d: 0.04151  loss_consistency_d: 0.003192     lr: 0.00010351  max_mem: 4886M
# [10/21 08:52:07 d2.utils.events]:  eta: 0:28:53  iter: 249  total_loss: 1.532  loss_cls: 0.5242  loss_box_reg: 0.6392  loss_rpn_cls: 0.06775  loss_rpn_loc: 0.2398  loss_image_d: 0.06942  loss_instance_d: 0.03124  loss_consistency_d: 0.005015     lr: 0.00012825  max_mem: 4886M
# [10/21 08:52:07 d2.utils.events]:  eta: 0:28:53  iter: 249  total_loss: 1.532  loss_cls: 0.5242  loss_box_reg: 0.6392  loss_rpn_cls: 0.06775  loss_rpn_loc: 0.2398  loss_image_d: 0.06942  loss_instance_d: 0.03124  loss_consistency_d: 0.005015     lr: 0.00012825  max_mem: 4886M
# [10/21 08:52:25 d2.utils.events]:  eta: 0:28:33  iter: 299  total_loss: 1.555  loss_cls: 0.4802  loss_box_reg: 0.6436  loss_rpn_cls: 0.08141  loss_rpn_loc: 0.2516  loss_image_d: 0.06934  loss_instance_d: 0.02238  loss_consistency_d: 0.008965     lr: 0.00015301  max_mem: 4886M
# [10/21 08:52:25 d2.utils.events]:  eta: 0:28:33  iter: 299  total_loss: 1.555  loss_cls: 0.4802  loss_box_reg: 0.6436  loss_rpn_cls: 0.08141  loss_rpn_loc: 0.2516  loss_image_d: 0.06934  loss_instance_d: 0.02238  loss_consistency_d: 0.008965     lr: 0.00015301  max_mem: 4886M
# [10/21 08:52:43 d2.utils.events]:  eta: 0:28:08  iter: 349  total_loss: 1.397  loss_cls: 0.4252  loss_box_reg: 0.5963  loss_rpn_cls: 0.06975  loss_rpn_loc: 0.1982  loss_image_d: 0.06939  loss_instance_d: 0.0158  loss_consistency_d: 0.01254     lr: 0.00017776  max_mem: 4886M
# [10/21 08:52:43 d2.utils.events]:  eta: 0:28:08  iter: 349  total_loss: 1.397  loss_cls: 0.4252  loss_box_reg: 0.5963  loss_rpn_cls: 0.06975  loss_rpn_loc: 0.1982  loss_image_d: 0.06939  loss_instance_d: 0.0158  loss_consistency_d: 0.01254     lr: 0.00017776  max_mem: 4886M
# [10/21 08:53:02 d2.utils.events]:  eta: 0:27:55  iter: 399  total_loss: 1.401  loss_cls: 0.4095  loss_box_reg: 0.5932  loss_rpn_cls: 0.06438  loss_rpn_loc: 0.1987  loss_image_d: 0.06935  loss_instance_d: 0.01207  loss_consistency_d: 0.01361     lr: 0.0002025  max_mem: 4886M
# [10/21 08:53:02 d2.utils.events]:  eta: 0:27:55  iter: 399  total_loss: 1.401  loss_cls: 0.4095  loss_box_reg: 0.5932  loss_rpn_cls: 0.06438  loss_rpn_loc: 0.1987  loss_image_d: 0.06935  loss_instance_d: 0.01207  loss_consistency_d: 0.01361     lr: 0.0002025  max_mem: 4886M
# [10/21 08:53:20 d2.utils.events]:  eta: 0:27:35  iter: 449  total_loss: 1.406  loss_cls: 0.4109  loss_box_reg: 0.583  loss_rpn_cls: 0.07282  loss_rpn_loc: 0.2169  loss_image_d: 0.06941  loss_instance_d: 0.009437  loss_consistency_d: 0.01379     lr: 0.00022726  max_mem: 4886M
# [10/21 08:53:20 d2.utils.events]:  eta: 0:27:35  iter: 449  total_loss: 1.406  loss_cls: 0.4109  loss_box_reg: 0.583  loss_rpn_cls: 0.07282  loss_rpn_loc: 0.2169  loss_image_d: 0.06941  loss_instance_d: 0.009437  loss_consistency_d: 0.01379     lr: 0.00022726  max_mem: 4886M
# [10/21 08:53:38 d2.utils.events]:  eta: 0:27:22  iter: 499  total_loss: 1.383  loss_cls: 0.3904  loss_box_reg: 0.5489  loss_rpn_cls: 0.07824  loss_rpn_loc: 0.2306  loss_image_d: 0.06949  loss_instance_d: 0.008297  loss_consistency_d: 0.01486     lr: 0.000252  max_mem: 4886M
# [10/21 08:53:38 d2.utils.events]:  eta: 0:27:22  iter: 499  total_loss: 1.383  loss_cls: 0.3904  loss_box_reg: 0.5489  loss_rpn_cls: 0.07824  loss_rpn_loc: 0.2306  loss_image_d: 0.06949  loss_instance_d: 0.008297  loss_consistency_d: 0.01486     lr: 0.000252  max_mem: 4886M
# [10/21 08:53:56 d2.utils.events]:  eta: 0:27:01  iter: 549  total_loss: 1.327  loss_cls: 0.4062  loss_box_reg: 0.533  loss_rpn_cls: 0.07051  loss_rpn_loc: 0.2338  loss_image_d: 0.06977  loss_instance_d: 0.00698  loss_consistency_d: 0.01452     lr: 0.00027676  max_mem: 4887M
# [10/21 08:53:56 d2.utils.events]:  eta: 0:27:01  iter: 549  total_loss: 1.327  loss_cls: 0.4062  loss_box_reg: 0.533  loss_rpn_cls: 0.07051  loss_rpn_loc: 0.2338  loss_image_d: 0.06977  loss_instance_d: 0.00698  loss_consistency_d: 0.01452     lr: 0.00027676  max_mem: 4887M
# [10/21 08:54:15 d2.utils.events]:  eta: 0:26:45  iter: 599  total_loss: 1.344  loss_cls: 0.3825  loss_box_reg: 0.5586  loss_rpn_cls: 0.06847  loss_rpn_loc: 0.2577  loss_image_d: 0.06986  loss_instance_d: 0.006388  loss_consistency_d: 0.01465     lr: 0.0003015  max_mem: 4887M
# [10/21 08:54:15 d2.utils.events]:  eta: 0:26:45  iter: 599  total_loss: 1.344  loss_cls: 0.3825  loss_box_reg: 0.5586  loss_rpn_cls: 0.06847  loss_rpn_loc: 0.2577  loss_image_d: 0.06986  loss_instance_d: 0.006388  loss_consistency_d: 0.01465     lr: 0.0003015  max_mem: 4887M
# [10/21 08:54:33 d2.utils.events]:  eta: 0:26:31  iter: 649  total_loss: 1.255  loss_cls: 0.3604  loss_box_reg: 0.5069  loss_rpn_cls: 0.06633  loss_rpn_loc: 0.2311  loss_image_d: 0.07015  loss_instance_d: 0.006392  loss_consistency_d: 0.01382     lr: 0.00032625  max_mem: 4887M
# [10/21 08:54:33 d2.utils.events]:  eta: 0:26:31  iter: 649  total_loss: 1.255  loss_cls: 0.3604  loss_box_reg: 0.5069  loss_rpn_cls: 0.06633  loss_rpn_loc: 0.2311  loss_image_d: 0.07015  loss_instance_d: 0.006392  loss_consistency_d: 0.01382     lr: 0.00032625  max_mem: 4887M
# [10/21 08:54:51 d2.utils.events]:  eta: 0:26:11  iter: 699  total_loss: 1.175  loss_cls: 0.3519  loss_box_reg: 0.4902  loss_rpn_cls: 0.05592  loss_rpn_loc: 0.1927  loss_image_d: 0.07068  loss_instance_d: 0.00524  loss_consistency_d: 0.01429     lr: 0.000351  max_mem: 4887M
# [10/21 08:54:51 d2.utils.events]:  eta: 0:26:11  iter: 699  total_loss: 1.175  loss_cls: 0.3519  loss_box_reg: 0.4902  loss_rpn_cls: 0.05592  loss_rpn_loc: 0.1927  loss_image_d: 0.07068  loss_instance_d: 0.00524  loss_consistency_d: 0.01429     lr: 0.000351  max_mem: 4887M
# [10/21 08:55:09 d2.utils.events]:  eta: 0:25:49  iter: 749  total_loss: 1.332  loss_cls: 0.4247  loss_box_reg: 0.5136  loss_rpn_cls: 0.06029  loss_rpn_loc: 0.2378  loss_image_d: 0.0709  loss_instance_d: 0.005531  loss_consistency_d: 0.01298     lr: 0.00037575  max_mem: 4887M
# [10/21 08:55:09 d2.utils.events]:  eta: 0:25:49  iter: 749  total_loss: 1.332  loss_cls: 0.4247  loss_box_reg: 0.5136  loss_rpn_cls: 0.06029  loss_rpn_loc: 0.2378  loss_image_d: 0.0709  loss_instance_d: 0.005531  loss_consistency_d: 0.01298     lr: 0.00037575  max_mem: 4887M
# [10/21 08:55:28 d2.utils.events]:  eta: 0:25:44  iter: 799  total_loss: 1.193  loss_cls: 0.3449  loss_box_reg: 0.4689  loss_rpn_cls: 0.06181  loss_rpn_loc: 0.2039  loss_image_d: 0.07115  loss_instance_d: 0.00511  loss_consistency_d: 0.0135     lr: 0.0004005  max_mem: 4887M
# [10/21 08:55:28 d2.utils.events]:  eta: 0:25:44  iter: 799  total_loss: 1.193  loss_cls: 0.3449  loss_box_reg: 0.4689  loss_rpn_cls: 0.06181  loss_rpn_loc: 0.2039  loss_image_d: 0.07115  loss_instance_d: 0.00511  loss_consistency_d: 0.0135     lr: 0.0004005  max_mem: 4887M
# [10/21 08:55:46 d2.utils.events]:  eta: 0:25:22  iter: 849  total_loss: 1.267  loss_cls: 0.3306  loss_box_reg: 0.5067  loss_rpn_cls: 0.05961  loss_rpn_loc: 0.2129  loss_image_d: 0.07158  loss_instance_d: 0.004214  loss_consistency_d: 0.01258     lr: 0.00042525  max_mem: 4887M
# [10/21 08:55:46 d2.utils.events]:  eta: 0:25:22  iter: 849  total_loss: 1.267  loss_cls: 0.3306  loss_box_reg: 0.5067  loss_rpn_cls: 0.05961  loss_rpn_loc: 0.2129  loss_image_d: 0.07158  loss_instance_d: 0.004214  loss_consistency_d: 0.01258     lr: 0.00042525  max_mem: 4887M
# [10/21 08:56:04 d2.utils.events]:  eta: 0:25:03  iter: 899  total_loss: 1.256  loss_cls: 0.3753  loss_box_reg: 0.4838  loss_rpn_cls: 0.06107  loss_rpn_loc: 0.2215  loss_image_d: 0.07225  loss_instance_d: 0.003954  loss_consistency_d: 0.01248     lr: 0.00045  max_mem: 4887M
# [10/21 08:56:04 d2.utils.events]:  eta: 0:25:03  iter: 899  total_loss: 1.256  loss_cls: 0.3753  loss_box_reg: 0.4838  loss_rpn_cls: 0.06107  loss_rpn_loc: 0.2215  loss_image_d: 0.07225  loss_instance_d: 0.003954  loss_consistency_d: 0.01248     lr: 0.00045  max_mem: 4887M
# [10/21 08:56:23 d2.utils.events]:  eta: 0:24:47  iter: 949  total_loss: 1.222  loss_cls: 0.3459  loss_box_reg: 0.4695  loss_rpn_cls: 0.06253  loss_rpn_loc: 0.2059  loss_image_d: 0.07268  loss_instance_d: 0.004039  loss_consistency_d: 0.01209     lr: 0.00047475  max_mem: 4887M
# [10/21 08:56:23 d2.utils.events]:  eta: 0:24:47  iter: 949  total_loss: 1.222  loss_cls: 0.3459  loss_box_reg: 0.4695  loss_rpn_cls: 0.06253  loss_rpn_loc: 0.2059  loss_image_d: 0.07268  loss_instance_d: 0.004039  loss_consistency_d: 0.01209     lr: 0.00047475  max_mem: 4887M
# [10/21 08:56:41 d2.utils.events]:  eta: 0:24:23  iter: 999  total_loss: 1.049  loss_cls: 0.2922  loss_box_reg: 0.421  loss_rpn_cls: 0.06092  loss_rpn_loc: 0.2178  loss_image_d: 0.07295  loss_instance_d: 0.004103  loss_consistency_d: 0.01173     lr: 0.00049951  max_mem: 4887M
# [10/21 08:56:41 d2.utils.events]:  eta: 0:24:23  iter: 999  total_loss: 1.049  loss_cls: 0.2922  loss_box_reg: 0.421  loss_rpn_cls: 0.06092  loss_rpn_loc: 0.2178  loss_image_d: 0.07295  loss_instance_d: 0.004103  loss_consistency_d: 0.01173     lr: 0.00049951  max_mem: 4887M
# [10/21 08:56:59 d2.utils.events]:  eta: 0:24:07  iter: 1049  total_loss: 1.07  loss_cls: 0.2964  loss_box_reg: 0.4532  loss_rpn_cls: 0.05688  loss_rpn_loc: 0.1777  loss_image_d: 0.07301  loss_instance_d: 0.003429  loss_consistency_d: 0.01203     lr: 0.0005  max_mem: 4887M
# [10/21 08:56:59 d2.utils.events]:  eta: 0:24:07  iter: 1049  total_loss: 1.07  loss_cls: 0.2964  loss_box_reg: 0.4532  loss_rpn_cls: 0.05688  loss_rpn_loc: 0.1777  loss_image_d: 0.07301  loss_instance_d: 0.003429  loss_consistency_d: 0.01203     lr: 0.0005  max_mem: 4887M
# [10/21 08:57:18 d2.utils.events]:  eta: 0:23:44  iter: 1099  total_loss: 1.196  loss_cls: 0.3652  loss_box_reg: 0.5007  loss_rpn_cls: 0.04682  loss_rpn_loc: 0.2116  loss_image_d: 0.07332  loss_instance_d: 0.002902  loss_consistency_d: 0.01185     lr: 0.0005  max_mem: 4887M
# [10/21 08:57:18 d2.utils.events]:  eta: 0:23:44  iter: 1099  total_loss: 1.196  loss_cls: 0.3652  loss_box_reg: 0.5007  loss_rpn_cls: 0.04682  loss_rpn_loc: 0.2116  loss_image_d: 0.07332  loss_instance_d: 0.002902  loss_consistency_d: 0.01185     lr: 0.0005  max_mem: 4887M
# [10/21 08:57:36 d2.utils.events]:  eta: 0:23:34  iter: 1149  total_loss: 1.126  loss_cls: 0.2942  loss_box_reg: 0.4367  loss_rpn_cls: 0.06691  loss_rpn_loc: 0.1915  loss_image_d: 0.07364  loss_instance_d: 0.003006  loss_consistency_d: 0.01155     lr: 0.0005  max_mem: 4887M
# [10/21 08:57:36 d2.utils.events]:  eta: 0:23:34  iter: 1149  total_loss: 1.126  loss_cls: 0.2942  loss_box_reg: 0.4367  loss_rpn_cls: 0.06691  loss_rpn_loc: 0.1915  loss_image_d: 0.07364  loss_instance_d: 0.003006  loss_consistency_d: 0.01155     lr: 0.0005  max_mem: 4887M
# [10/21 08:57:54 d2.utils.events]:  eta: 0:23:13  iter: 1199  total_loss: 1.138  loss_cls: 0.3379  loss_box_reg: 0.4942  loss_rpn_cls: 0.05661  loss_rpn_loc: 0.1769  loss_image_d: 0.07365  loss_instance_d: 0.002481  loss_consistency_d: 0.01164     lr: 0.0005  max_mem: 4887M
# [10/21 08:57:54 d2.utils.events]:  eta: 0:23:13  iter: 1199  total_loss: 1.138  loss_cls: 0.3379  loss_box_reg: 0.4942  loss_rpn_cls: 0.05661  loss_rpn_loc: 0.1769  loss_image_d: 0.07365  loss_instance_d: 0.002481  loss_consistency_d: 0.01164     lr: 0.0005  max_mem: 4887M
# [10/21 08:58:13 d2.utils.events]:  eta: 0:22:51  iter: 1249  total_loss: 1.065  loss_cls: 0.284  loss_box_reg: 0.4449  loss_rpn_cls: 0.05264  loss_rpn_loc: 0.1745  loss_image_d: 0.07361  loss_instance_d: 0.002503  loss_consistency_d: 0.0118     lr: 0.0005  max_mem: 4887M
# [10/21 08:58:13 d2.utils.events]:  eta: 0:22:51  iter: 1249  total_loss: 1.065  loss_cls: 0.284  loss_box_reg: 0.4449  loss_rpn_cls: 0.05264  loss_rpn_loc: 0.1745  loss_image_d: 0.07361  loss_instance_d: 0.002503  loss_consistency_d: 0.0118     lr: 0.0005  max_mem: 4887M
# [10/21 08:58:31 d2.utils.events]:  eta: 0:22:41  iter: 1299  total_loss: 1.185  loss_cls: 0.3398  loss_box_reg: 0.4878  loss_rpn_cls: 0.05931  loss_rpn_loc: 0.2203  loss_image_d: 0.07385  loss_instance_d: 0.002806  loss_consistency_d: 0.01135     lr: 0.0005  max_mem: 4887M
# [10/21 08:58:31 d2.utils.events]:  eta: 0:22:41  iter: 1299  total_loss: 1.185  loss_cls: 0.3398  loss_box_reg: 0.4878  loss_rpn_cls: 0.05931  loss_rpn_loc: 0.2203  loss_image_d: 0.07385  loss_instance_d: 0.002806  loss_consistency_d: 0.01135     lr: 0.0005  max_mem: 4887M
# [10/21 08:58:49 d2.utils.events]:  eta: 0:22:18  iter: 1349  total_loss: 1.256  loss_cls: 0.3298  loss_box_reg: 0.4863  loss_rpn_cls: 0.06432  loss_rpn_loc: 0.2486  loss_image_d: 0.07372  loss_instance_d: 0.00251  loss_consistency_d: 0.01159     lr: 0.0005  max_mem: 4887M
# [10/21 08:58:49 d2.utils.events]:  eta: 0:22:18  iter: 1349  total_loss: 1.256  loss_cls: 0.3298  loss_box_reg: 0.4863  loss_rpn_cls: 0.06432  loss_rpn_loc: 0.2486  loss_image_d: 0.07372  loss_instance_d: 0.00251  loss_consistency_d: 0.01159     lr: 0.0005  max_mem: 4887M
# [10/21 08:59:08 d2.utils.events]:  eta: 0:22:05  iter: 1399  total_loss: 1.117  loss_cls: 0.3163  loss_box_reg: 0.4703  loss_rpn_cls: 0.04252  loss_rpn_loc: 0.2033  loss_image_d: 0.07408  loss_instance_d: 0.002487  loss_consistency_d: 0.01149     lr: 0.0005  max_mem: 4887M
# [10/21 08:59:08 d2.utils.events]:  eta: 0:22:05  iter: 1399  total_loss: 1.117  loss_cls: 0.3163  loss_box_reg: 0.4703  loss_rpn_cls: 0.04252  loss_rpn_loc: 0.2033  loss_image_d: 0.07408  loss_instance_d: 0.002487  loss_consistency_d: 0.01149     lr: 0.0005  max_mem: 4887M
# [10/21 08:59:26 d2.utils.events]:  eta: 0:21:46  iter: 1449  total_loss: 1.102  loss_cls: 0.3063  loss_box_reg: 0.4372  loss_rpn_cls: 0.05554  loss_rpn_loc: 0.1874  loss_image_d: 0.07429  loss_instance_d: 0.001902  loss_consistency_d: 0.01159     lr: 0.0005  max_mem: 4887M
# [10/21 08:59:26 d2.utils.events]:  eta: 0:21:46  iter: 1449  total_loss: 1.102  loss_cls: 0.3063  loss_box_reg: 0.4372  loss_rpn_cls: 0.05554  loss_rpn_loc: 0.1874  loss_image_d: 0.07429  loss_instance_d: 0.001902  loss_consistency_d: 0.01159     lr: 0.0005  max_mem: 4887M
# [10/21 08:59:45 d2.utils.events]:  eta: 0:22:27  iter: 1499  total_loss: 1.053  loss_cls: 0.2966  loss_box_reg: 0.4427  loss_rpn_cls: 0.05155  loss_rpn_loc: 0.1691  loss_image_d: 0.07408  loss_instance_d: 0.002183  loss_consistency_d: 0.0118     lr: 0.0005  max_mem: 4887M
# [10/21 08:59:45 d2.utils.events]:  eta: 0:22:27  iter: 1499  total_loss: 1.053  loss_cls: 0.2966  loss_box_reg: 0.4427  loss_rpn_cls: 0.05155  loss_rpn_loc: 0.1691  loss_image_d: 0.07408  loss_instance_d: 0.002183  loss_consistency_d: 0.0118     lr: 0.0005  max_mem: 4887M
# [10/21 09:00:04 d2.utils.events]:  eta: 0:21:37  iter: 1549  total_loss: 1.068  loss_cls: 0.2912  loss_box_reg: 0.4224  loss_rpn_cls: 0.04724  loss_rpn_loc: 0.1953  loss_image_d: 0.07403  loss_instance_d: 0.001987  loss_consistency_d: 0.0118     lr: 0.0005  max_mem: 4887M
# [10/21 09:00:04 d2.utils.events]:  eta: 0:21:37  iter: 1549  total_loss: 1.068  loss_cls: 0.2912  loss_box_reg: 0.4224  loss_rpn_cls: 0.04724  loss_rpn_loc: 0.1953  loss_image_d: 0.07403  loss_instance_d: 0.001987  loss_consistency_d: 0.0118     lr: 0.0005  max_mem: 4887M
# [10/21 09:00:23 d2.utils.events]:  eta: 0:21:02  iter: 1599  total_loss: 1.091  loss_cls: 0.3113  loss_box_reg: 0.4642  loss_rpn_cls: 0.04886  loss_rpn_loc: 0.2091  loss_image_d: 0.07429  loss_instance_d: 0.00165  loss_consistency_d: 0.01153     lr: 0.0005  max_mem: 4887M
# [10/21 09:00:23 d2.utils.events]:  eta: 0:21:02  iter: 1599  total_loss: 1.091  loss_cls: 0.3113  loss_box_reg: 0.4642  loss_rpn_cls: 0.04886  loss_rpn_loc: 0.2091  loss_image_d: 0.07429  loss_instance_d: 0.00165  loss_consistency_d: 0.01153     lr: 0.0005  max_mem: 4887M
# [10/21 09:00:41 d2.utils.events]:  eta: 0:20:47  iter: 1649  total_loss: 1.128  loss_cls: 0.3177  loss_box_reg: 0.4654  loss_rpn_cls: 0.06073  loss_rpn_loc: 0.21  loss_image_d: 0.07425  loss_instance_d: 0.002249  loss_consistency_d: 0.01142     lr: 0.0005  max_mem: 4887M
# [10/21 09:00:41 d2.utils.events]:  eta: 0:20:47  iter: 1649  total_loss: 1.128  loss_cls: 0.3177  loss_box_reg: 0.4654  loss_rpn_cls: 0.06073  loss_rpn_loc: 0.21  loss_image_d: 0.07425  loss_instance_d: 0.002249  loss_consistency_d: 0.01142     lr: 0.0005  max_mem: 4887M
# [10/21 09:01:00 d2.utils.events]:  eta: 0:20:22  iter: 1699  total_loss: 1.142  loss_cls: 0.3128  loss_box_reg: 0.4951  loss_rpn_cls: 0.04585  loss_rpn_loc: 0.206  loss_image_d: 0.07425  loss_instance_d: 0.001905  loss_consistency_d: 0.01165     lr: 0.0005  max_mem: 4887M
# [10/21 09:01:00 d2.utils.events]:  eta: 0:20:22  iter: 1699  total_loss: 1.142  loss_cls: 0.3128  loss_box_reg: 0.4951  loss_rpn_cls: 0.04585  loss_rpn_loc: 0.206  loss_image_d: 0.07425  loss_instance_d: 0.001905  loss_consistency_d: 0.01165     lr: 0.0005  max_mem: 4887M
# [10/21 09:01:18 d2.utils.events]:  eta: 0:20:02  iter: 1749  total_loss: 1.168  loss_cls: 0.3354  loss_box_reg: 0.4623  loss_rpn_cls: 0.04602  loss_rpn_loc: 0.1964  loss_image_d: 0.07397  loss_instance_d: 0.001696  loss_consistency_d: 0.01179     lr: 0.0005  max_mem: 4887M
# [10/21 09:01:18 d2.utils.events]:  eta: 0:20:02  iter: 1749  total_loss: 1.168  loss_cls: 0.3354  loss_box_reg: 0.4623  loss_rpn_cls: 0.04602  loss_rpn_loc: 0.1964  loss_image_d: 0.07397  loss_instance_d: 0.001696  loss_consistency_d: 0.01179     lr: 0.0005  max_mem: 4887M
# [10/21 09:01:37 d2.utils.events]:  eta: 0:19:41  iter: 1799  total_loss: 1.131  loss_cls: 0.3086  loss_box_reg: 0.4527  loss_rpn_cls: 0.05032  loss_rpn_loc: 0.1949  loss_image_d: 0.07402  loss_instance_d: 0.001711  loss_consistency_d: 0.0117     lr: 0.0005  max_mem: 4887M
# [10/21 09:01:37 d2.utils.events]:  eta: 0:19:41  iter: 1799  total_loss: 1.131  loss_cls: 0.3086  loss_box_reg: 0.4527  loss_rpn_cls: 0.05032  loss_rpn_loc: 0.1949  loss_image_d: 0.07402  loss_instance_d: 0.001711  loss_consistency_d: 0.0117     lr: 0.0005  max_mem: 4887M
# [10/21 09:01:55 d2.utils.events]:  eta: 0:19:28  iter: 1849  total_loss: 1.076  loss_cls: 0.3213  loss_box_reg: 0.4767  loss_rpn_cls: 0.04768  loss_rpn_loc: 0.1958  loss_image_d: 0.07402  loss_instance_d: 0.001579  loss_consistency_d: 0.012     lr: 0.0005  max_mem: 4887M
# [10/21 09:01:55 d2.utils.events]:  eta: 0:19:28  iter: 1849  total_loss: 1.076  loss_cls: 0.3213  loss_box_reg: 0.4767  loss_rpn_cls: 0.04768  loss_rpn_loc: 0.1958  loss_image_d: 0.07402  loss_instance_d: 0.001579  loss_consistency_d: 0.012     lr: 0.0005  max_mem: 4887M
# [10/21 09:02:14 d2.utils.events]:  eta: 0:19:05  iter: 1899  total_loss: 1.058  loss_cls: 0.3141  loss_box_reg: 0.4362  loss_rpn_cls: 0.04713  loss_rpn_loc: 0.1858  loss_image_d: 0.07426  loss_instance_d: 0.001593  loss_consistency_d: 0.01169     lr: 0.0005  max_mem: 4887M
# [10/21 09:02:14 d2.utils.events]:  eta: 0:19:05  iter: 1899  total_loss: 1.058  loss_cls: 0.3141  loss_box_reg: 0.4362  loss_rpn_cls: 0.04713  loss_rpn_loc: 0.1858  loss_image_d: 0.07426  loss_instance_d: 0.001593  loss_consistency_d: 0.01169     lr: 0.0005  max_mem: 4887M
# [10/21 09:02:33 d2.utils.events]:  eta: 0:18:54  iter: 1949  total_loss: 1.113  loss_cls: 0.2973  loss_box_reg: 0.4578  loss_rpn_cls: 0.0412  loss_rpn_loc: 0.1941  loss_image_d: 0.07398  loss_instance_d: 0.001354  loss_consistency_d: 0.01196     lr: 0.0005  max_mem: 4887M
# [10/21 09:02:33 d2.utils.events]:  eta: 0:18:54  iter: 1949  total_loss: 1.113  loss_cls: 0.2973  loss_box_reg: 0.4578  loss_rpn_cls: 0.0412  loss_rpn_loc: 0.1941  loss_image_d: 0.07398  loss_instance_d: 0.001354  loss_consistency_d: 0.01196     lr: 0.0005  max_mem: 4887M
# [10/21 09:02:51 d2.utils.events]:  eta: 0:18:29  iter: 1999  total_loss: 1.113  loss_cls: 0.3  loss_box_reg: 0.4543  loss_rpn_cls: 0.06319  loss_rpn_loc: 0.1979  loss_image_d: 0.07397  loss_instance_d: 0.001503  loss_consistency_d: 0.01175     lr: 0.0005  max_mem: 4887M
# [10/21 09:02:51 d2.utils.events]:  eta: 0:18:29  iter: 1999  total_loss: 1.113  loss_cls: 0.3  loss_box_reg: 0.4543  loss_rpn_cls: 0.06319  loss_rpn_loc: 0.1979  loss_image_d: 0.07397  loss_instance_d: 0.001503  loss_consistency_d: 0.01175     lr: 0.0005  max_mem: 4887M
# [10/21 09:03:10 d2.utils.events]:  eta: 0:18:09  iter: 2049  total_loss: 1.051  loss_cls: 0.2939  loss_box_reg: 0.4397  loss_rpn_cls: 0.04171  loss_rpn_loc: 0.1717  loss_image_d: 0.07429  loss_instance_d: 0.001109  loss_consistency_d: 0.01203     lr: 0.0005  max_mem: 4887M
# [10/21 09:03:10 d2.utils.events]:  eta: 0:18:09  iter: 2049  total_loss: 1.051  loss_cls: 0.2939  loss_box_reg: 0.4397  loss_rpn_cls: 0.04171  loss_rpn_loc: 0.1717  loss_image_d: 0.07429  loss_instance_d: 0.001109  loss_consistency_d: 0.01203     lr: 0.0005  max_mem: 4887M
# [10/21 09:03:28 d2.utils.events]:  eta: 0:17:49  iter: 2099  total_loss: 1.1  loss_cls: 0.2976  loss_box_reg: 0.4388  loss_rpn_cls: 0.04852  loss_rpn_loc: 0.2175  loss_image_d: 0.07436  loss_instance_d: 0.001215  loss_consistency_d: 0.01174     lr: 0.0005  max_mem: 4887M
# [10/21 09:03:28 d2.utils.events]:  eta: 0:17:49  iter: 2099  total_loss: 1.1  loss_cls: 0.2976  loss_box_reg: 0.4388  loss_rpn_cls: 0.04852  loss_rpn_loc: 0.2175  loss_image_d: 0.07436  loss_instance_d: 0.001215  loss_consistency_d: 0.01174     lr: 0.0005  max_mem: 4887M
# [10/21 09:03:47 d2.utils.events]:  eta: 0:17:39  iter: 2149  total_loss: 1.091  loss_cls: 0.2984  loss_box_reg: 0.4485  loss_rpn_cls: 0.04766  loss_rpn_loc: 0.1876  loss_image_d: 0.07408  loss_instance_d: 0.0009877  loss_consistency_d: 0.012     lr: 0.0005  max_mem: 4887M
# [10/21 09:03:47 d2.utils.events]:  eta: 0:17:39  iter: 2149  total_loss: 1.091  loss_cls: 0.2984  loss_box_reg: 0.4485  loss_rpn_cls: 0.04766  loss_rpn_loc: 0.1876  loss_image_d: 0.07408  loss_instance_d: 0.0009877  loss_consistency_d: 0.012     lr: 0.0005  max_mem: 4887M
# [10/21 09:04:05 d2.utils.events]:  eta: 0:17:19  iter: 2199  total_loss: 1.094  loss_cls: 0.3004  loss_box_reg: 0.46  loss_rpn_cls: 0.05186  loss_rpn_loc: 0.1966  loss_image_d: 0.07406  loss_instance_d: 0.001179  loss_consistency_d: 0.01186     lr: 0.0005  max_mem: 4887M
# [10/21 09:04:05 d2.utils.events]:  eta: 0:17:19  iter: 2199  total_loss: 1.094  loss_cls: 0.3004  loss_box_reg: 0.46  loss_rpn_cls: 0.05186  loss_rpn_loc: 0.1966  loss_image_d: 0.07406  loss_instance_d: 0.001179  loss_consistency_d: 0.01186     lr: 0.0005  max_mem: 4887M
# [10/21 09:04:24 d2.utils.events]:  eta: 0:16:58  iter: 2249  total_loss: 1.023  loss_cls: 0.3077  loss_box_reg: 0.4316  loss_rpn_cls: 0.04056  loss_rpn_loc: 0.2033  loss_image_d: 0.07416  loss_instance_d: 0.001149  loss_consistency_d: 0.01183     lr: 0.0005  max_mem: 4887M
# [10/21 09:04:24 d2.utils.events]:  eta: 0:16:58  iter: 2249  total_loss: 1.023  loss_cls: 0.3077  loss_box_reg: 0.4316  loss_rpn_cls: 0.04056  loss_rpn_loc: 0.2033  loss_image_d: 0.07416  loss_instance_d: 0.001149  loss_consistency_d: 0.01183     lr: 0.0005  max_mem: 4887M
# [10/21 09:04:42 d2.utils.events]:  eta: 0:16:42  iter: 2299  total_loss: 1.091  loss_cls: 0.2911  loss_box_reg: 0.4396  loss_rpn_cls: 0.04516  loss_rpn_loc: 0.205  loss_image_d: 0.07417  loss_instance_d: 0.0008613  loss_consistency_d: 0.01201     lr: 0.0005  max_mem: 4887M
# [10/21 09:04:42 d2.utils.events]:  eta: 0:16:42  iter: 2299  total_loss: 1.091  loss_cls: 0.2911  loss_box_reg: 0.4396  loss_rpn_cls: 0.04516  loss_rpn_loc: 0.205  loss_image_d: 0.07417  loss_instance_d: 0.0008613  loss_consistency_d: 0.01201     lr: 0.0005  max_mem: 4887M
# [10/21 09:05:01 d2.utils.events]:  eta: 0:16:25  iter: 2349  total_loss: 1.071  loss_cls: 0.2873  loss_box_reg: 0.4384  loss_rpn_cls: 0.04457  loss_rpn_loc: 0.1913  loss_image_d: 0.07462  loss_instance_d: 0.0009744  loss_consistency_d: 0.01188     lr: 0.0005  max_mem: 4887M
# [10/21 09:05:01 d2.utils.events]:  eta: 0:16:25  iter: 2349  total_loss: 1.071  loss_cls: 0.2873  loss_box_reg: 0.4384  loss_rpn_cls: 0.04457  loss_rpn_loc: 0.1913  loss_image_d: 0.07462  loss_instance_d: 0.0009744  loss_consistency_d: 0.01188     lr: 0.0005  max_mem: 4887M
# [10/21 09:05:19 d2.utils.events]:  eta: 0:16:05  iter: 2399  total_loss: 1.098  loss_cls: 0.3014  loss_box_reg: 0.4417  loss_rpn_cls: 0.05389  loss_rpn_loc: 0.1829  loss_image_d: 0.0741  loss_instance_d: 0.0008251  loss_consistency_d: 0.01209     lr: 0.0005  max_mem: 4888M
# [10/21 09:05:19 d2.utils.events]:  eta: 0:16:05  iter: 2399  total_loss: 1.098  loss_cls: 0.3014  loss_box_reg: 0.4417  loss_rpn_cls: 0.05389  loss_rpn_loc: 0.1829  loss_image_d: 0.0741  loss_instance_d: 0.0008251  loss_consistency_d: 0.01209     lr: 0.0005  max_mem: 4888M
# [10/21 09:05:38 d2.utils.events]:  eta: 0:15:43  iter: 2449  total_loss: 1.041  loss_cls: 0.2998  loss_box_reg: 0.3749  loss_rpn_cls: 0.0412  loss_rpn_loc: 0.1635  loss_image_d: 0.0742  loss_instance_d: 0.0007677  loss_consistency_d: 0.01207     lr: 0.0005  max_mem: 4888M
# [10/21 09:05:38 d2.utils.events]:  eta: 0:15:43  iter: 2449  total_loss: 1.041  loss_cls: 0.2998  loss_box_reg: 0.3749  loss_rpn_cls: 0.0412  loss_rpn_loc: 0.1635  loss_image_d: 0.0742  loss_instance_d: 0.0007677  loss_consistency_d: 0.01207     lr: 0.0005  max_mem: 4888M
# [10/21 09:05:56 d2.utils.events]:  eta: 0:15:25  iter: 2499  total_loss: 1.039  loss_cls: 0.28  loss_box_reg: 0.4318  loss_rpn_cls: 0.04769  loss_rpn_loc: 0.1901  loss_image_d: 0.07393  loss_instance_d: 0.0008937  loss_consistency_d: 0.01207     lr: 0.0005  max_mem: 4888M
# [10/21 09:05:56 d2.utils.events]:  eta: 0:15:25  iter: 2499  total_loss: 1.039  loss_cls: 0.28  loss_box_reg: 0.4318  loss_rpn_cls: 0.04769  loss_rpn_loc: 0.1901  loss_image_d: 0.07393  loss_instance_d: 0.0008937  loss_consistency_d: 0.01207     lr: 0.0005  max_mem: 4888M
# [10/21 09:06:15 d2.utils.events]:  eta: 0:15:08  iter: 2549  total_loss: 1.1  loss_cls: 0.2979  loss_box_reg: 0.4173  loss_rpn_cls: 0.05064  loss_rpn_loc: 0.2092  loss_image_d: 0.07377  loss_instance_d: 0.0009335  loss_consistency_d: 0.01225     lr: 0.0005  max_mem: 4888M
# [10/21 09:06:15 d2.utils.events]:  eta: 0:15:08  iter: 2549  total_loss: 1.1  loss_cls: 0.2979  loss_box_reg: 0.4173  loss_rpn_cls: 0.05064  loss_rpn_loc: 0.2092  loss_image_d: 0.07377  loss_instance_d: 0.0009335  loss_consistency_d: 0.01225     lr: 0.0005  max_mem: 4888M
# [10/21 09:06:33 d2.utils.events]:  eta: 0:14:51  iter: 2599  total_loss: 1.071  loss_cls: 0.2923  loss_box_reg: 0.4311  loss_rpn_cls: 0.04759  loss_rpn_loc: 0.2021  loss_image_d: 0.07387  loss_instance_d: 0.0009551  loss_consistency_d: 0.01223     lr: 0.0005  max_mem: 4888M
# [10/21 09:06:33 d2.utils.events]:  eta: 0:14:51  iter: 2599  total_loss: 1.071  loss_cls: 0.2923  loss_box_reg: 0.4311  loss_rpn_cls: 0.04759  loss_rpn_loc: 0.2021  loss_image_d: 0.07387  loss_instance_d: 0.0009551  loss_consistency_d: 0.01223     lr: 0.0005  max_mem: 4888M
# [10/21 09:06:52 d2.utils.events]:  eta: 0:14:34  iter: 2649  total_loss: 1.053  loss_cls: 0.2966  loss_box_reg: 0.4156  loss_rpn_cls: 0.05412  loss_rpn_loc: 0.2005  loss_image_d: 0.07413  loss_instance_d: 0.000834  loss_consistency_d: 0.01204     lr: 0.0005  max_mem: 4888M
# [10/21 09:06:52 d2.utils.events]:  eta: 0:14:34  iter: 2649  total_loss: 1.053  loss_cls: 0.2966  loss_box_reg: 0.4156  loss_rpn_cls: 0.05412  loss_rpn_loc: 0.2005  loss_image_d: 0.07413  loss_instance_d: 0.000834  loss_consistency_d: 0.01204     lr: 0.0005  max_mem: 4888M
# [10/21 09:07:11 d2.utils.events]:  eta: 0:14:14  iter: 2699  total_loss: 1.052  loss_cls: 0.2779  loss_box_reg: 0.4388  loss_rpn_cls: 0.04516  loss_rpn_loc: 0.2048  loss_image_d: 0.07417  loss_instance_d: 0.0006931  loss_consistency_d: 0.01221     lr: 0.0005  max_mem: 4888M
# [10/21 09:07:11 d2.utils.events]:  eta: 0:14:14  iter: 2699  total_loss: 1.052  loss_cls: 0.2779  loss_box_reg: 0.4388  loss_rpn_cls: 0.04516  loss_rpn_loc: 0.2048  loss_image_d: 0.07417  loss_instance_d: 0.0006931  loss_consistency_d: 0.01221     lr: 0.0005  max_mem: 4888M
# [10/21 09:07:29 d2.utils.events]:  eta: 0:13:56  iter: 2749  total_loss: 1.006  loss_cls: 0.311  loss_box_reg: 0.4187  loss_rpn_cls: 0.04085  loss_rpn_loc: 0.1667  loss_image_d: 0.07407  loss_instance_d: 0.0005643  loss_consistency_d: 0.01209     lr: 0.0005  max_mem: 4888M
# [10/21 09:07:29 d2.utils.events]:  eta: 0:13:56  iter: 2749  total_loss: 1.006  loss_cls: 0.311  loss_box_reg: 0.4187  loss_rpn_cls: 0.04085  loss_rpn_loc: 0.1667  loss_image_d: 0.07407  loss_instance_d: 0.0005643  loss_consistency_d: 0.01209     lr: 0.0005  max_mem: 4888M
# [10/21 09:07:48 d2.utils.events]:  eta: 0:13:35  iter: 2799  total_loss: 1.098  loss_cls: 0.3153  loss_box_reg: 0.4463  loss_rpn_cls: 0.04735  loss_rpn_loc: 0.1848  loss_image_d: 0.07423  loss_instance_d: 0.0007435  loss_consistency_d: 0.0122     lr: 0.0005  max_mem: 4888M
# [10/21 09:07:48 d2.utils.events]:  eta: 0:13:35  iter: 2799  total_loss: 1.098  loss_cls: 0.3153  loss_box_reg: 0.4463  loss_rpn_cls: 0.04735  loss_rpn_loc: 0.1848  loss_image_d: 0.07423  loss_instance_d: 0.0007435  loss_consistency_d: 0.0122     lr: 0.0005  max_mem: 4888M
# [10/21 09:08:06 d2.utils.events]:  eta: 0:13:17  iter: 2849  total_loss: 1.103  loss_cls: 0.3348  loss_box_reg: 0.4735  loss_rpn_cls: 0.04362  loss_rpn_loc: 0.1557  loss_image_d: 0.07403  loss_instance_d: 0.0007801  loss_consistency_d: 0.01206     lr: 0.0005  max_mem: 4888M
# [10/21 09:08:06 d2.utils.events]:  eta: 0:13:17  iter: 2849  total_loss: 1.103  loss_cls: 0.3348  loss_box_reg: 0.4735  loss_rpn_cls: 0.04362  loss_rpn_loc: 0.1557  loss_image_d: 0.07403  loss_instance_d: 0.0007801  loss_consistency_d: 0.01206     lr: 0.0005  max_mem: 4888M
# [10/21 09:08:25 d2.utils.events]:  eta: 0:13:02  iter: 2899  total_loss: 1.167  loss_cls: 0.3268  loss_box_reg: 0.483  loss_rpn_cls: 0.0434  loss_rpn_loc: 0.2152  loss_image_d: 0.07392  loss_instance_d: 0.0008893  loss_consistency_d: 0.01208     lr: 0.0005  max_mem: 4888M
# [10/21 09:08:25 d2.utils.events]:  eta: 0:13:02  iter: 2899  total_loss: 1.167  loss_cls: 0.3268  loss_box_reg: 0.483  loss_rpn_cls: 0.0434  loss_rpn_loc: 0.2152  loss_image_d: 0.07392  loss_instance_d: 0.0008893  loss_consistency_d: 0.01208     lr: 0.0005  max_mem: 4888M
# [10/21 09:08:44 d2.utils.events]:  eta: 0:12:43  iter: 2949  total_loss: 1.156  loss_cls: 0.2966  loss_box_reg: 0.472  loss_rpn_cls: 0.05063  loss_rpn_loc: 0.2251  loss_image_d: 0.07408  loss_instance_d: 0.0008004  loss_consistency_d: 0.01216     lr: 0.0005  max_mem: 4888M
# [10/21 09:08:44 d2.utils.events]:  eta: 0:12:43  iter: 2949  total_loss: 1.156  loss_cls: 0.2966  loss_box_reg: 0.472  loss_rpn_cls: 0.05063  loss_rpn_loc: 0.2251  loss_image_d: 0.07408  loss_instance_d: 0.0008004  loss_consistency_d: 0.01216     lr: 0.0005  max_mem: 4888M
# [10/21 09:09:02 d2.utils.events]:  eta: 0:12:20  iter: 2999  total_loss: 1.055  loss_cls: 0.2806  loss_box_reg: 0.4089  loss_rpn_cls: 0.05009  loss_rpn_loc: 0.1796  loss_image_d: 0.07432  loss_instance_d: 0.0007457  loss_consistency_d: 0.01205     lr: 0.0005  max_mem: 4888M
# [10/21 09:09:02 d2.utils.events]:  eta: 0:12:20  iter: 2999  total_loss: 1.055  loss_cls: 0.2806  loss_box_reg: 0.4089  loss_rpn_cls: 0.05009  loss_rpn_loc: 0.1796  loss_image_d: 0.07432  loss_instance_d: 0.0007457  loss_consistency_d: 0.01205     lr: 0.0005  max_mem: 4888M
# [10/21 09:09:21 d2.utils.events]:  eta: 0:12:01  iter: 3049  total_loss: 1.031  loss_cls: 0.2969  loss_box_reg: 0.4256  loss_rpn_cls: 0.04252  loss_rpn_loc: 0.1953  loss_image_d: 0.07388  loss_instance_d: 0.0008138  loss_consistency_d: 0.01216     lr: 0.0005  max_mem: 4888M
# [10/21 09:09:21 d2.utils.events]:  eta: 0:12:01  iter: 3049  total_loss: 1.031  loss_cls: 0.2969  loss_box_reg: 0.4256  loss_rpn_cls: 0.04252  loss_rpn_loc: 0.1953  loss_image_d: 0.07388  loss_instance_d: 0.0008138  loss_consistency_d: 0.01216     lr: 0.0005  max_mem: 4888M
# [10/21 09:09:39 d2.utils.events]:  eta: 0:11:45  iter: 3099  total_loss: 1.088  loss_cls: 0.2858  loss_box_reg: 0.4385  loss_rpn_cls: 0.03813  loss_rpn_loc: 0.2083  loss_image_d: 0.07407  loss_instance_d: 0.0006015  loss_consistency_d: 0.01227     lr: 0.0005  max_mem: 4888M
# [10/21 09:09:39 d2.utils.events]:  eta: 0:11:45  iter: 3099  total_loss: 1.088  loss_cls: 0.2858  loss_box_reg: 0.4385  loss_rpn_cls: 0.03813  loss_rpn_loc: 0.2083  loss_image_d: 0.07407  loss_instance_d: 0.0006015  loss_consistency_d: 0.01227     lr: 0.0005  max_mem: 4888M
# [10/21 09:09:58 d2.utils.events]:  eta: 0:11:31  iter: 3149  total_loss: 1.037  loss_cls: 0.295  loss_box_reg: 0.4529  loss_rpn_cls: 0.04811  loss_rpn_loc: 0.2188  loss_image_d: 0.07411  loss_instance_d: 0.0005981  loss_consistency_d: 0.01191     lr: 0.0005  max_mem: 4888M
# [10/21 09:09:58 d2.utils.events]:  eta: 0:11:31  iter: 3149  total_loss: 1.037  loss_cls: 0.295  loss_box_reg: 0.4529  loss_rpn_cls: 0.04811  loss_rpn_loc: 0.2188  loss_image_d: 0.07411  loss_instance_d: 0.0005981  loss_consistency_d: 0.01191     lr: 0.0005  max_mem: 4888M
# [10/21 09:10:16 d2.utils.events]:  eta: 0:11:08  iter: 3199  total_loss: 1.06  loss_cls: 0.2993  loss_box_reg: 0.4222  loss_rpn_cls: 0.04513  loss_rpn_loc: 0.2155  loss_image_d: 0.07415  loss_instance_d: 0.0005643  loss_consistency_d: 0.01193     lr: 0.0005  max_mem: 4888M
# [10/21 09:10:16 d2.utils.events]:  eta: 0:11:08  iter: 3199  total_loss: 1.06  loss_cls: 0.2993  loss_box_reg: 0.4222  loss_rpn_cls: 0.04513  loss_rpn_loc: 0.2155  loss_image_d: 0.07415  loss_instance_d: 0.0005643  loss_consistency_d: 0.01193     lr: 0.0005  max_mem: 4888M
# [10/21 09:10:35 d2.utils.events]:  eta: 0:10:48  iter: 3249  total_loss: 1.119  loss_cls: 0.3156  loss_box_reg: 0.4613  loss_rpn_cls: 0.04555  loss_rpn_loc: 0.2003  loss_image_d: 0.07404  loss_instance_d: 0.0006969  loss_consistency_d: 0.01214     lr: 0.0005  max_mem: 4888M
# [10/21 09:10:35 d2.utils.events]:  eta: 0:10:48  iter: 3249  total_loss: 1.119  loss_cls: 0.3156  loss_box_reg: 0.4613  loss_rpn_cls: 0.04555  loss_rpn_loc: 0.2003  loss_image_d: 0.07404  loss_instance_d: 0.0006969  loss_consistency_d: 0.01214     lr: 0.0005  max_mem: 4888M
# [10/21 09:10:53 d2.utils.events]:  eta: 0:10:29  iter: 3299  total_loss: 0.9944  loss_cls: 0.2832  loss_box_reg: 0.4232  loss_rpn_cls: 0.03697  loss_rpn_loc: 0.1507  loss_image_d: 0.07375  loss_instance_d: 0.0006403  loss_consistency_d: 0.01223     lr: 0.0005  max_mem: 4888M
# [10/21 09:10:53 d2.utils.events]:  eta: 0:10:29  iter: 3299  total_loss: 0.9944  loss_cls: 0.2832  loss_box_reg: 0.4232  loss_rpn_cls: 0.03697  loss_rpn_loc: 0.1507  loss_image_d: 0.07375  loss_instance_d: 0.0006403  loss_consistency_d: 0.01223     lr: 0.0005  max_mem: 4888M
# [10/21 09:11:12 d2.utils.events]:  eta: 0:10:16  iter: 3349  total_loss: 1.061  loss_cls: 0.282  loss_box_reg: 0.3823  loss_rpn_cls: 0.05145  loss_rpn_loc: 0.2229  loss_image_d: 0.07388  loss_instance_d: 0.0005511  loss_consistency_d: 0.01239     lr: 0.0005  max_mem: 4888M
# [10/21 09:11:12 d2.utils.events]:  eta: 0:10:16  iter: 3349  total_loss: 1.061  loss_cls: 0.282  loss_box_reg: 0.3823  loss_rpn_cls: 0.05145  loss_rpn_loc: 0.2229  loss_image_d: 0.07388  loss_instance_d: 0.0005511  loss_consistency_d: 0.01239     lr: 0.0005  max_mem: 4888M
# [10/21 09:11:31 d2.utils.events]:  eta: 0:09:56  iter: 3399  total_loss: 1.109  loss_cls: 0.3009  loss_box_reg: 0.4408  loss_rpn_cls: 0.04234  loss_rpn_loc: 0.237  loss_image_d: 0.07397  loss_instance_d: 0.0005496  loss_consistency_d: 0.01221     lr: 0.0005  max_mem: 4888M
# [10/21 09:11:31 d2.utils.events]:  eta: 0:09:56  iter: 3399  total_loss: 1.109  loss_cls: 0.3009  loss_box_reg: 0.4408  loss_rpn_cls: 0.04234  loss_rpn_loc: 0.237  loss_image_d: 0.07397  loss_instance_d: 0.0005496  loss_consistency_d: 0.01221     lr: 0.0005  max_mem: 4888M
# [10/21 09:11:49 d2.utils.events]:  eta: 0:09:35  iter: 3449  total_loss: 0.9998  loss_cls: 0.3019  loss_box_reg: 0.4133  loss_rpn_cls: 0.04909  loss_rpn_loc: 0.1551  loss_image_d: 0.0739  loss_instance_d: 0.0006104  loss_consistency_d: 0.01222     lr: 0.0005  max_mem: 4888M
# [10/21 09:11:49 d2.utils.events]:  eta: 0:09:35  iter: 3449  total_loss: 0.9998  loss_cls: 0.3019  loss_box_reg: 0.4133  loss_rpn_cls: 0.04909  loss_rpn_loc: 0.1551  loss_image_d: 0.0739  loss_instance_d: 0.0006104  loss_consistency_d: 0.01222     lr: 0.0005  max_mem: 4888M
# [10/21 09:12:08 d2.utils.events]:  eta: 0:09:19  iter: 3499  total_loss: 0.9939  loss_cls: 0.2745  loss_box_reg: 0.4311  loss_rpn_cls: 0.03753  loss_rpn_loc: 0.1927  loss_image_d: 0.07386  loss_instance_d: 0.0006779  loss_consistency_d: 0.01236     lr: 0.0005  max_mem: 4888M
# [10/21 09:12:08 d2.utils.events]:  eta: 0:09:19  iter: 3499  total_loss: 0.9939  loss_cls: 0.2745  loss_box_reg: 0.4311  loss_rpn_cls: 0.03753  loss_rpn_loc: 0.1927  loss_image_d: 0.07386  loss_instance_d: 0.0006779  loss_consistency_d: 0.01236     lr: 0.0005  max_mem: 4888M
# [10/21 09:12:27 d2.utils.events]:  eta: 0:09:01  iter: 3549  total_loss: 1.067  loss_cls: 0.3086  loss_box_reg: 0.4601  loss_rpn_cls: 0.03582  loss_rpn_loc: 0.1889  loss_image_d: 0.07401  loss_instance_d: 0.0006574  loss_consistency_d: 0.01236     lr: 0.0005  max_mem: 4888M
# [10/21 09:12:27 d2.utils.events]:  eta: 0:09:01  iter: 3549  total_loss: 1.067  loss_cls: 0.3086  loss_box_reg: 0.4601  loss_rpn_cls: 0.03582  loss_rpn_loc: 0.1889  loss_image_d: 0.07401  loss_instance_d: 0.0006574  loss_consistency_d: 0.01236     lr: 0.0005  max_mem: 4888M
# [10/21 09:12:45 d2.utils.events]:  eta: 0:08:42  iter: 3599  total_loss: 1.084  loss_cls: 0.2928  loss_box_reg: 0.4212  loss_rpn_cls: 0.0526  loss_rpn_loc: 0.2098  loss_image_d: 0.07413  loss_instance_d: 0.0006251  loss_consistency_d: 0.0123     lr: 0.0005  max_mem: 4888M
# [10/21 09:12:45 d2.utils.events]:  eta: 0:08:42  iter: 3599  total_loss: 1.084  loss_cls: 0.2928  loss_box_reg: 0.4212  loss_rpn_cls: 0.0526  loss_rpn_loc: 0.2098  loss_image_d: 0.07413  loss_instance_d: 0.0006251  loss_consistency_d: 0.0123     lr: 0.0005  max_mem: 4888M
# [10/21 09:13:04 d2.utils.events]:  eta: 0:08:23  iter: 3649  total_loss: 1.02  loss_cls: 0.274  loss_box_reg: 0.4214  loss_rpn_cls: 0.0456  loss_rpn_loc: 0.185  loss_image_d: 0.07394  loss_instance_d: 0.0005463  loss_consistency_d: 0.0122     lr: 0.0005  max_mem: 4888M
# [10/21 09:13:04 d2.utils.events]:  eta: 0:08:23  iter: 3649  total_loss: 1.02  loss_cls: 0.274  loss_box_reg: 0.4214  loss_rpn_cls: 0.0456  loss_rpn_loc: 0.185  loss_image_d: 0.07394  loss_instance_d: 0.0005463  loss_consistency_d: 0.0122     lr: 0.0005  max_mem: 4888M
# [10/21 09:13:23 d2.utils.events]:  eta: 0:08:04  iter: 3699  total_loss: 1.063  loss_cls: 0.3001  loss_box_reg: 0.4425  loss_rpn_cls: 0.04166  loss_rpn_loc: 0.185  loss_image_d: 0.07408  loss_instance_d: 0.0004832  loss_consistency_d: 0.01225     lr: 0.0005  max_mem: 4888M
# [10/21 09:13:23 d2.utils.events]:  eta: 0:08:04  iter: 3699  total_loss: 1.063  loss_cls: 0.3001  loss_box_reg: 0.4425  loss_rpn_cls: 0.04166  loss_rpn_loc: 0.185  loss_image_d: 0.07408  loss_instance_d: 0.0004832  loss_consistency_d: 0.01225     lr: 0.0005  max_mem: 4888M
# [10/21 09:13:41 d2.utils.events]:  eta: 0:07:47  iter: 3749  total_loss: 1.033  loss_cls: 0.3006  loss_box_reg: 0.4486  loss_rpn_cls: 0.04137  loss_rpn_loc: 0.1594  loss_image_d: 0.07417  loss_instance_d: 0.0004667  loss_consistency_d: 0.01218     lr: 0.0005  max_mem: 4888M
# [10/21 09:13:41 d2.utils.events]:  eta: 0:07:47  iter: 3749  total_loss: 1.033  loss_cls: 0.3006  loss_box_reg: 0.4486  loss_rpn_cls: 0.04137  loss_rpn_loc: 0.1594  loss_image_d: 0.07417  loss_instance_d: 0.0004667  loss_consistency_d: 0.01218     lr: 0.0005  max_mem: 4888M
# [10/21 09:14:00 d2.utils.events]:  eta: 0:07:28  iter: 3799  total_loss: 1.034  loss_cls: 0.2851  loss_box_reg: 0.4401  loss_rpn_cls: 0.03507  loss_rpn_loc: 0.1868  loss_image_d: 0.07407  loss_instance_d: 0.0004629  loss_consistency_d: 0.01218     lr: 0.0005  max_mem: 4888M
# [10/21 09:14:00 d2.utils.events]:  eta: 0:07:28  iter: 3799  total_loss: 1.034  loss_cls: 0.2851  loss_box_reg: 0.4401  loss_rpn_cls: 0.03507  loss_rpn_loc: 0.1868  loss_image_d: 0.07407  loss_instance_d: 0.0004629  loss_consistency_d: 0.01218     lr: 0.0005  max_mem: 4888M
# [10/21 09:14:19 d2.utils.events]:  eta: 0:07:09  iter: 3849  total_loss: 1.087  loss_cls: 0.2961  loss_box_reg: 0.4379  loss_rpn_cls: 0.04627  loss_rpn_loc: 0.1933  loss_image_d: 0.07418  loss_instance_d: 0.0005293  loss_consistency_d: 0.01203     lr: 0.0005  max_mem: 4888M
# [10/21 09:14:19 d2.utils.events]:  eta: 0:07:09  iter: 3849  total_loss: 1.087  loss_cls: 0.2961  loss_box_reg: 0.4379  loss_rpn_cls: 0.04627  loss_rpn_loc: 0.1933  loss_image_d: 0.07418  loss_instance_d: 0.0005293  loss_consistency_d: 0.01203     lr: 0.0005  max_mem: 4888M
# [10/21 09:14:37 d2.utils.events]:  eta: 0:06:51  iter: 3899  total_loss: 1.045  loss_cls: 0.2767  loss_box_reg: 0.4363  loss_rpn_cls: 0.04167  loss_rpn_loc: 0.1896  loss_image_d: 0.0741  loss_instance_d: 0.0005767  loss_consistency_d: 0.01215     lr: 0.0005  max_mem: 4888M
# [10/21 09:14:37 d2.utils.events]:  eta: 0:06:51  iter: 3899  total_loss: 1.045  loss_cls: 0.2767  loss_box_reg: 0.4363  loss_rpn_cls: 0.04167  loss_rpn_loc: 0.1896  loss_image_d: 0.0741  loss_instance_d: 0.0005767  loss_consistency_d: 0.01215     lr: 0.0005  max_mem: 4888M
# [10/21 09:14:56 d2.utils.events]:  eta: 0:06:32  iter: 3949  total_loss: 1.072  loss_cls: 0.288  loss_box_reg: 0.4456  loss_rpn_cls: 0.04203  loss_rpn_loc: 0.1852  loss_image_d: 0.07412  loss_instance_d: 0.0004555  loss_consistency_d: 0.01218     lr: 0.0005  max_mem: 4888M
# [10/21 09:14:56 d2.utils.events]:  eta: 0:06:32  iter: 3949  total_loss: 1.072  loss_cls: 0.288  loss_box_reg: 0.4456  loss_rpn_cls: 0.04203  loss_rpn_loc: 0.1852  loss_image_d: 0.07412  loss_instance_d: 0.0004555  loss_consistency_d: 0.01218     lr: 0.0005  max_mem: 4888M
# [10/21 09:15:15 d2.utils.events]:  eta: 0:06:14  iter: 3999  total_loss: 0.9721  loss_cls: 0.2537  loss_box_reg: 0.3756  loss_rpn_cls: 0.04599  loss_rpn_loc: 0.2033  loss_image_d: 0.07383  loss_instance_d: 0.0004863  loss_consistency_d: 0.01209     lr: 0.0005  max_mem: 4888M
# [10/21 09:15:15 d2.utils.events]:  eta: 0:06:14  iter: 3999  total_loss: 0.9721  loss_cls: 0.2537  loss_box_reg: 0.3756  loss_rpn_cls: 0.04599  loss_rpn_loc: 0.2033  loss_image_d: 0.07383  loss_instance_d: 0.0004863  loss_consistency_d: 0.01209     lr: 0.0005  max_mem: 4888M
# [10/21 09:15:33 d2.utils.events]:  eta: 0:05:54  iter: 4049  total_loss: 0.9838  loss_cls: 0.2811  loss_box_reg: 0.4473  loss_rpn_cls: 0.04166  loss_rpn_loc: 0.1786  loss_image_d: 0.07408  loss_instance_d: 0.0005648  loss_consistency_d: 0.01216     lr: 0.0005  max_mem: 4888M
# [10/21 09:15:33 d2.utils.events]:  eta: 0:05:54  iter: 4049  total_loss: 0.9838  loss_cls: 0.2811  loss_box_reg: 0.4473  loss_rpn_cls: 0.04166  loss_rpn_loc: 0.1786  loss_image_d: 0.07408  loss_instance_d: 0.0005648  loss_consistency_d: 0.01216     lr: 0.0005  max_mem: 4888M
# [10/21 09:15:52 d2.utils.events]:  eta: 0:05:36  iter: 4099  total_loss: 1.006  loss_cls: 0.2782  loss_box_reg: 0.4116  loss_rpn_cls: 0.04191  loss_rpn_loc: 0.179  loss_image_d: 0.07406  loss_instance_d: 0.000445  loss_consistency_d: 0.01204     lr: 0.0005  max_mem: 4888M
# [10/21 09:15:52 d2.utils.events]:  eta: 0:05:36  iter: 4099  total_loss: 1.006  loss_cls: 0.2782  loss_box_reg: 0.4116  loss_rpn_cls: 0.04191  loss_rpn_loc: 0.179  loss_image_d: 0.07406  loss_instance_d: 0.000445  loss_consistency_d: 0.01204     lr: 0.0005  max_mem: 4888M
# [10/21 09:16:11 d2.utils.events]:  eta: 0:05:17  iter: 4149  total_loss: 1.02  loss_cls: 0.2847  loss_box_reg: 0.4181  loss_rpn_cls: 0.04321  loss_rpn_loc: 0.1926  loss_image_d: 0.07384  loss_instance_d: 0.0005774  loss_consistency_d: 0.01224     lr: 0.0005  max_mem: 4888M
# [10/21 09:16:11 d2.utils.events]:  eta: 0:05:17  iter: 4149  total_loss: 1.02  loss_cls: 0.2847  loss_box_reg: 0.4181  loss_rpn_cls: 0.04321  loss_rpn_loc: 0.1926  loss_image_d: 0.07384  loss_instance_d: 0.0005774  loss_consistency_d: 0.01224     lr: 0.0005  max_mem: 4888M
# [10/21 09:16:30 d2.utils.events]:  eta: 0:04:59  iter: 4199  total_loss: 0.9969  loss_cls: 0.2609  loss_box_reg: 0.4129  loss_rpn_cls: 0.03989  loss_rpn_loc: 0.166  loss_image_d: 0.07399  loss_instance_d: 0.0005273  loss_consistency_d: 0.0121     lr: 0.0005  max_mem: 4888M
# [10/21 09:16:30 d2.utils.events]:  eta: 0:04:59  iter: 4199  total_loss: 0.9969  loss_cls: 0.2609  loss_box_reg: 0.4129  loss_rpn_cls: 0.03989  loss_rpn_loc: 0.166  loss_image_d: 0.07399  loss_instance_d: 0.0005273  loss_consistency_d: 0.0121     lr: 0.0005  max_mem: 4888M
# [10/21 09:16:48 d2.utils.events]:  eta: 0:04:40  iter: 4249  total_loss: 1.042  loss_cls: 0.2752  loss_box_reg: 0.4196  loss_rpn_cls: 0.04125  loss_rpn_loc: 0.193  loss_image_d: 0.07382  loss_instance_d: 0.0003827  loss_consistency_d: 0.01233     lr: 0.0005  max_mem: 4888M
# [10/21 09:16:48 d2.utils.events]:  eta: 0:04:40  iter: 4249  total_loss: 1.042  loss_cls: 0.2752  loss_box_reg: 0.4196  loss_rpn_cls: 0.04125  loss_rpn_loc: 0.193  loss_image_d: 0.07382  loss_instance_d: 0.0003827  loss_consistency_d: 0.01233     lr: 0.0005  max_mem: 4888M
# [10/21 09:17:07 d2.utils.events]:  eta: 0:04:22  iter: 4299  total_loss: 0.9725  loss_cls: 0.2837  loss_box_reg: 0.4172  loss_rpn_cls: 0.03411  loss_rpn_loc: 0.1632  loss_image_d: 0.07386  loss_instance_d: 0.0003799  loss_consistency_d: 0.01232     lr: 0.0005  max_mem: 4888M
# [10/21 09:17:07 d2.utils.events]:  eta: 0:04:22  iter: 4299  total_loss: 0.9725  loss_cls: 0.2837  loss_box_reg: 0.4172  loss_rpn_cls: 0.03411  loss_rpn_loc: 0.1632  loss_image_d: 0.07386  loss_instance_d: 0.0003799  loss_consistency_d: 0.01232     lr: 0.0005  max_mem: 4888M
# [10/21 09:17:26 d2.utils.events]:  eta: 0:04:03  iter: 4349  total_loss: 1.07  loss_cls: 0.2954  loss_box_reg: 0.4121  loss_rpn_cls: 0.04087  loss_rpn_loc: 0.1836  loss_image_d: 0.07379  loss_instance_d: 0.0005785  loss_consistency_d: 0.0123     lr: 0.0005  max_mem: 4888M
# [10/21 09:17:26 d2.utils.events]:  eta: 0:04:03  iter: 4349  total_loss: 1.07  loss_cls: 0.2954  loss_box_reg: 0.4121  loss_rpn_cls: 0.04087  loss_rpn_loc: 0.1836  loss_image_d: 0.07379  loss_instance_d: 0.0005785  loss_consistency_d: 0.0123     lr: 0.0005  max_mem: 4888M
# [10/21 09:17:44 d2.utils.events]:  eta: 0:03:44  iter: 4399  total_loss: 1.001  loss_cls: 0.2863  loss_box_reg: 0.4301  loss_rpn_cls: 0.03259  loss_rpn_loc: 0.1977  loss_image_d: 0.07401  loss_instance_d: 0.0004536  loss_consistency_d: 0.01206     lr: 0.0005  max_mem: 4888M
# [10/21 09:17:44 d2.utils.events]:  eta: 0:03:44  iter: 4399  total_loss: 1.001  loss_cls: 0.2863  loss_box_reg: 0.4301  loss_rpn_cls: 0.03259  loss_rpn_loc: 0.1977  loss_image_d: 0.07401  loss_instance_d: 0.0004536  loss_consistency_d: 0.01206     lr: 0.0005  max_mem: 4888M
# [10/21 09:18:03 d2.utils.events]:  eta: 0:03:25  iter: 4449  total_loss: 1.04  loss_cls: 0.2781  loss_box_reg: 0.4143  loss_rpn_cls: 0.04065  loss_rpn_loc: 0.1824  loss_image_d: 0.07422  loss_instance_d: 0.0004095  loss_consistency_d: 0.0121     lr: 0.0005  max_mem: 4888M
# [10/21 09:18:03 d2.utils.events]:  eta: 0:03:25  iter: 4449  total_loss: 1.04  loss_cls: 0.2781  loss_box_reg: 0.4143  loss_rpn_cls: 0.04065  loss_rpn_loc: 0.1824  loss_image_d: 0.07422  loss_instance_d: 0.0004095  loss_consistency_d: 0.0121     lr: 0.0005  max_mem: 4888M
# [10/21 09:18:22 d2.utils.events]:  eta: 0:03:06  iter: 4499  total_loss: 1.061  loss_cls: 0.2924  loss_box_reg: 0.4299  loss_rpn_cls: 0.0384  loss_rpn_loc: 0.2114  loss_image_d: 0.07423  loss_instance_d: 0.000465  loss_consistency_d: 0.012     lr: 0.0005  max_mem: 4888M
# [10/21 09:18:22 d2.utils.events]:  eta: 0:03:06  iter: 4499  total_loss: 1.061  loss_cls: 0.2924  loss_box_reg: 0.4299  loss_rpn_cls: 0.0384  loss_rpn_loc: 0.2114  loss_image_d: 0.07423  loss_instance_d: 0.000465  loss_consistency_d: 0.012     lr: 0.0005  max_mem: 4888M
# [10/21 09:18:40 d2.utils.events]:  eta: 0:02:48  iter: 4549  total_loss: 0.957  loss_cls: 0.254  loss_box_reg: 0.4065  loss_rpn_cls: 0.0461  loss_rpn_loc: 0.1401  loss_image_d: 0.07387  loss_instance_d: 0.0004052  loss_consistency_d: 0.01219     lr: 0.0005  max_mem: 4888M
# [10/21 09:18:40 d2.utils.events]:  eta: 0:02:48  iter: 4549  total_loss: 0.957  loss_cls: 0.254  loss_box_reg: 0.4065  loss_rpn_cls: 0.0461  loss_rpn_loc: 0.1401  loss_image_d: 0.07387  loss_instance_d: 0.0004052  loss_consistency_d: 0.01219     lr: 0.0005  max_mem: 4888M
# [10/21 09:18:59 d2.utils.events]:  eta: 0:02:28  iter: 4599  total_loss: 0.9836  loss_cls: 0.2662  loss_box_reg: 0.4313  loss_rpn_cls: 0.03851  loss_rpn_loc: 0.1717  loss_image_d: 0.07405  loss_instance_d: 0.0004429  loss_consistency_d: 0.01214     lr: 0.0005  max_mem: 4888M
# [10/21 09:18:59 d2.utils.events]:  eta: 0:02:28  iter: 4599  total_loss: 0.9836  loss_cls: 0.2662  loss_box_reg: 0.4313  loss_rpn_cls: 0.03851  loss_rpn_loc: 0.1717  loss_image_d: 0.07405  loss_instance_d: 0.0004429  loss_consistency_d: 0.01214     lr: 0.0005  max_mem: 4888M
# [10/21 09:19:18 d2.utils.events]:  eta: 0:02:11  iter: 4649  total_loss: 1.01  loss_cls: 0.2882  loss_box_reg: 0.4233  loss_rpn_cls: 0.03926  loss_rpn_loc: 0.1742  loss_image_d: 0.07416  loss_instance_d: 0.0004839  loss_consistency_d: 0.01211     lr: 0.0005  max_mem: 4888M
# [10/21 09:19:18 d2.utils.events]:  eta: 0:02:11  iter: 4649  total_loss: 1.01  loss_cls: 0.2882  loss_box_reg: 0.4233  loss_rpn_cls: 0.03926  loss_rpn_loc: 0.1742  loss_image_d: 0.07416  loss_instance_d: 0.0004839  loss_consistency_d: 0.01211     lr: 0.0005  max_mem: 4888M
# [10/21 09:19:36 d2.utils.events]:  eta: 0:01:51  iter: 4699  total_loss: 0.9523  loss_cls: 0.2646  loss_box_reg: 0.3868  loss_rpn_cls: 0.03871  loss_rpn_loc: 0.1769  loss_image_d: 0.07391  loss_instance_d: 0.0004553  loss_consistency_d: 0.01219     lr: 0.0005  max_mem: 4888M
# [10/21 09:19:36 d2.utils.events]:  eta: 0:01:51  iter: 4699  total_loss: 0.9523  loss_cls: 0.2646  loss_box_reg: 0.3868  loss_rpn_cls: 0.03871  loss_rpn_loc: 0.1769  loss_image_d: 0.07391  loss_instance_d: 0.0004553  loss_consistency_d: 0.01219     lr: 0.0005  max_mem: 4888M
# [10/21 09:19:55 d2.utils.events]:  eta: 0:01:33  iter: 4749  total_loss: 0.9773  loss_cls: 0.2901  loss_box_reg: 0.4252  loss_rpn_cls: 0.04351  loss_rpn_loc: 0.1583  loss_image_d: 0.07393  loss_instance_d: 0.0003914  loss_consistency_d: 0.01227     lr: 0.0005  max_mem: 4888M
# [10/21 09:19:55 d2.utils.events]:  eta: 0:01:33  iter: 4749  total_loss: 0.9773  loss_cls: 0.2901  loss_box_reg: 0.4252  loss_rpn_cls: 0.04351  loss_rpn_loc: 0.1583  loss_image_d: 0.07393  loss_instance_d: 0.0003914  loss_consistency_d: 0.01227     lr: 0.0005  max_mem: 4888M
# [10/21 09:20:14 d2.utils.events]:  eta: 0:01:14  iter: 4799  total_loss: 1.045  loss_cls: 0.2801  loss_box_reg: 0.4391  loss_rpn_cls: 0.04083  loss_rpn_loc: 0.1723  loss_image_d: 0.07404  loss_instance_d: 0.0003602  loss_consistency_d: 0.01225     lr: 0.0005  max_mem: 4888M
# [10/21 09:20:14 d2.utils.events]:  eta: 0:01:14  iter: 4799  total_loss: 1.045  loss_cls: 0.2801  loss_box_reg: 0.4391  loss_rpn_cls: 0.04083  loss_rpn_loc: 0.1723  loss_image_d: 0.07404  loss_instance_d: 0.0003602  loss_consistency_d: 0.01225     lr: 0.0005  max_mem: 4888M
# [10/21 09:20:32 d2.utils.events]:  eta: 0:00:55  iter: 4849  total_loss: 1.058  loss_cls: 0.3008  loss_box_reg: 0.4493  loss_rpn_cls: 0.04082  loss_rpn_loc: 0.1994  loss_image_d: 0.07399  loss_instance_d: 0.0004686  loss_consistency_d: 0.01219     lr: 0.0005  max_mem: 4888M
# [10/21 09:20:32 d2.utils.events]:  eta: 0:00:55  iter: 4849  total_loss: 1.058  loss_cls: 0.3008  loss_box_reg: 0.4493  loss_rpn_cls: 0.04082  loss_rpn_loc: 0.1994  loss_image_d: 0.07399  loss_instance_d: 0.0004686  loss_consistency_d: 0.01219     lr: 0.0005  max_mem: 4888M
# [10/21 09:20:51 d2.utils.events]:  eta: 0:00:37  iter: 4899  total_loss: 1.01  loss_cls: 0.2693  loss_box_reg: 0.4081  loss_rpn_cls: 0.03289  loss_rpn_loc: 0.1903  loss_image_d: 0.07384  loss_instance_d: 0.0004301  loss_consistency_d: 0.01225     lr: 0.0005  max_mem: 4888M
# [10/21 09:20:51 d2.utils.events]:  eta: 0:00:37  iter: 4899  total_loss: 1.01  loss_cls: 0.2693  loss_box_reg: 0.4081  loss_rpn_cls: 0.03289  loss_rpn_loc: 0.1903  loss_image_d: 0.07384  loss_instance_d: 0.0004301  loss_consistency_d: 0.01225     lr: 0.0005  max_mem: 4888M
# [10/21 09:21:10 d2.utils.events]:  eta: 0:00:18  iter: 4949  total_loss: 0.987  loss_cls: 0.2634  loss_box_reg: 0.3961  loss_rpn_cls: 0.03799  loss_rpn_loc: 0.2059  loss_image_d: 0.0741  loss_instance_d: 0.0003656  loss_consistency_d: 0.01209     lr: 0.0005  max_mem: 4888M
# [10/21 09:21:10 d2.utils.events]:  eta: 0:00:18  iter: 4949  total_loss: 0.987  loss_cls: 0.2634  loss_box_reg: 0.3961  loss_rpn_cls: 0.03799  loss_rpn_loc: 0.2059  loss_image_d: 0.0741  loss_instance_d: 0.0003656  loss_consistency_d: 0.01209     lr: 0.0005  max_mem: 4888M
# [10/21 09:21:28 d2.utils.events]:  eta: 0:00:00  iter: 4999  total_loss: 1.041  loss_cls: 0.2999  loss_box_reg: 0.4485  loss_rpn_cls: 0.03735  loss_rpn_loc: 0.1901  loss_image_d: 0.07386  loss_instance_d: 0.0004138  loss_consistency_d: 0.01222     lr: 0.0005  max_mem: 4888M
# [10/21 09:21:28 d2.utils.events]:  eta: 0:00:00  iter: 4999  total_loss: 1.041  loss_cls: 0.2999  loss_box_reg: 0.4485  loss_rpn_cls: 0.03735  loss_rpn_loc: 0.1901  loss_image_d: 0.07386  loss_instance_d: 0.0004138  loss_consistency_d: 0.01222     lr: 0.0005  max_mem: 4888M

# %% [markdown]
# ##Evalutate the performance
# runt the PascalVOCDetectionEvaluator if your annotations are in PASCAL VOC otherwhise run the COCOEvaluator<br>
#
# The mAP50 is the object detection result on the dataset. In this case, for the cityscape dataset, the result is 39.5%

# %%
#PASCAL VOC evaluation
from detectron2.evaluation import inference_on_dataset, PascalVOCDetectionEvaluator
from detectron2.data import build_detection_test_loader
evaluator = PascalVOCDetectionEvaluator("city_testT")
val_loader = build_detection_test_loader(cfg_source, "city_testT")
res = inference_on_dataset(model, val_loader, evaluator)
print(res)
# Out:
# [10/21 09:40:20 d2.data.build]: Distribution of instances among all 8 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |    car     | 4667         |   person   | 3419         |   rider    | 556          |
# |   truck    | 93           |    bus     | 98           |   train    | 23           |
# | motorcycle | 149          |  bicycle   | 1175         |            |              |
# |   total    | 10180        |            |              |            |              |
# [10/21 09:40:20 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=1333, sample_style='choice')]
# [10/21 09:40:20 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/21 09:40:20 d2.data.common]: Serializing 500 elements to byte tensors and concatenating them all ...
# [10/21 09:40:20 d2.data.common]: Serialized dataset takes 0.73 MiB
# [10/21 09:40:20 d2.evaluation.evaluator]: Start inference on 500 batches
# [10/21 09:40:20 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=1333, sample_style='choice')]
# [10/21 09:40:20 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/21 09:40:20 d2.data.common]: Serializing 500 elements to byte tensors and concatenating them all ...
# [10/21 09:40:20 d2.data.common]: Serialized dataset takes 0.73 MiB
# [10/21 09:40:20 d2.evaluation.evaluator]: Start inference on 500 batches
# [10/21 09:40:20 d2.evaluation.evaluator]: Inference done 11/500. Dataloading: 0.0010 s/iter. Inference: 0.0490 s/iter. Eval: 0.0003 s/iter. Total: 0.0503 s/iter. ETA=0:00:24
# [10/21 09:40:20 d2.evaluation.evaluator]: Inference done 11/500. Dataloading: 0.0010 s/iter. Inference: 0.0490 s/iter. Eval: 0.0003 s/iter. Total: 0.0503 s/iter. ETA=0:00:24
# [10/21 09:40:25 d2.evaluation.evaluator]: Inference done 111/500. Dataloading: 0.0012 s/iter. Inference: 0.0490 s/iter. Eval: 0.0003 s/iter. Total: 0.0505 s/iter. ETA=0:00:19
# [10/21 09:40:25 d2.evaluation.evaluator]: Inference done 111/500. Dataloading: 0.0012 s/iter. Inference: 0.0490 s/iter. Eval: 0.0003 s/iter. Total: 0.0505 s/iter. ETA=0:00:19
# [10/21 09:40:30 d2.evaluation.evaluator]: Inference done 210/500. Dataloading: 0.0012 s/iter. Inference: 0.0490 s/iter. Eval: 0.0003 s/iter. Total: 0.0506 s/iter. ETA=0:00:14
# [10/21 09:40:30 d2.evaluation.evaluator]: Inference done 210/500. Dataloading: 0.0012 s/iter. Inference: 0.0490 s/iter. Eval: 0.0003 s/iter. Total: 0.0506 s/iter. ETA=0:00:14
# [10/21 09:40:35 d2.evaluation.evaluator]: Inference done 309/500. Dataloading: 0.0012 s/iter. Inference: 0.0491 s/iter. Eval: 0.0003 s/iter. Total: 0.0506 s/iter. ETA=0:00:09
# [10/21 09:40:35 d2.evaluation.evaluator]: Inference done 309/500. Dataloading: 0.0012 s/iter. Inference: 0.0491 s/iter. Eval: 0.0003 s/iter. Total: 0.0506 s/iter. ETA=0:00:09
# [10/21 09:40:40 d2.evaluation.evaluator]: Inference done 408/500. Dataloading: 0.0012 s/iter. Inference: 0.0492 s/iter. Eval: 0.0003 s/iter. Total: 0.0507 s/iter. ETA=0:00:04
# [10/21 09:40:40 d2.evaluation.evaluator]: Inference done 408/500. Dataloading: 0.0012 s/iter. Inference: 0.0492 s/iter. Eval: 0.0003 s/iter. Total: 0.0507 s/iter. ETA=0:00:04
# [10/21 09:40:45 d2.evaluation.evaluator]: Total inference time: 0:00:25.138286 (0.050784 s / iter per device, on 1 devices)
# [10/21 09:40:45 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:24 (0.049227 s / iter per device, on 1 devices)
# [10/21 09:40:45 d2.evaluation.pascal_voc_evaluation]: Evaluating city_testT using 2007 metric. Note that results do not use the official Matlab API.
# [10/21 09:40:45 d2.evaluation.evaluator]: Total inference time: 0:00:25.138286 (0.050784 s / iter per device, on 1 devices)
# [10/21 09:40:45 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:24 (0.049227 s / iter per device, on 1 devices)
# [10/21 09:40:45 d2.evaluation.pascal_voc_evaluation]: Evaluating city_testT using 2007 metric. Note that results do not use the official Matlab API.
# OrderedDict([('bbox', {'AP': 32.53046032450565, 'AP50': 55.10706411902311, 'AP75': 31.85100464059785})])
# OrderedDict([('bbox', {'AP': 32.53046032450565, 'AP50': 55.10706411902311, 'AP75': 31.85100464059785})])

# %%
# 短测训练（使用本地权重）：加载本地 model_final_b275ba.pkl 并运行小规模训练
print("=== 短测训练（本地权重）===")
# 覆盖 cfg 为小规模并指向本地权重
cfg_source.MODEL.WEIGHTS = "/mnt/lyh/DA-FasterCNN/model_final_b275ba.pkl"
cfg_source.SOLVER.MAX_ITER = 50
cfg_source.SOLVER.IMS_PER_BATCH = 2
cfg_source.DATALOADER.NUM_WORKERS = 0
cfg_source.SOLVER.CHECKPOINT_PERIOD = 50

cfg_target.SOLVER.IMS_PER_BATCH = 2

# 重新构建模型
model = build_model(cfg_source)
print("Model built with local weights")

# 运行短测训练
try:
    do_train(cfg_source, cfg_target, model, resume=False)
    print("短测训练完成")
except Exception as e:
    import traceback
    print("短测训练失败:")
    traceback.print_exc()
